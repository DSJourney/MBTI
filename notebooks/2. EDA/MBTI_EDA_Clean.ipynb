# %% [markdown]
# # MBTI Project - Exploratory Data Analysis
# <br>

# %% [markdown]
# <div class="span5 alert alert-info">
# <h3>Introduction</h3>
#     <p>This section comes after the <b>Data Wrangling</b> step. In the following lines of code you will find my Exploratory Data Analysis. This step involves creating plots and charts to understand the relationship between data and the features of that data.<p>
# </div>

# %% [markdown]
# <br>
#
# ### Table of Contents
#
# - [Importing Libraries](#importing)
# - [Review of our Dataset](#review)
# - [Dropping columns](#drop)
# - [Color Setting](#colors)
# - [Visualizations](#visuals)
#     - [16 MBTI Types](#visuals)
#      - [Heatmap](#heatmap)
#      - [Boxplot - Avg. Number of Characters](#characters)
#      - [Boxplot - Avg. Number of Links](#links)
#      - [Boxplot - Avg. Use of Emoticons](#emoticons)
#      - [Boxplot - Avg. Self-mentions and mentions of other MBTI types](#mentions)
#      - [Boxplot - Avg. Use of Pronouns](#pronouns)
#      - [Boxplot - Avg. Use of Positive & Negative words](#posneg)<br>
#     - [4 dichotomies](#dicho)
#      - [Heatmap](#heatmapd)
#      - [Boxplot - Avg. Number of Characters](#charactersd)
#      - [Boxplot - Avg. Number of Links](#linksd)
#      - [Boxplot - Avg. Use of Emoticons](#emoticonsd)
#      - [Boxplot - Avg. Self-mentions and mentions of other MBTI types](#mentionsd)
#      - [Boxplot - Avg. Use of Pronouns](#pronounsd)
#      - [Boxplot - Avg. Use of Positive & Negative words](#posnegd)
#      <br>
#
# <b>Note: The boxplot sections also include some statistical analysis</b>

# %% [markdown]
# <a id=importing></a>

# %% [markdown]
# ## Imports
# ***

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import matplotlib.transforms
from matplotlib.patches import Patch
import seaborn as sns
import re
from scipy import stats

# %matplotlib inline
sns.set(rc={'axes.facecolor':'white'})

# %%
df = pd.read_csv('../../data/mbti_interim.csv', index_col=0)

# %% [markdown]
# <a id=review></a>

# %% [markdown]
# <br>
#
#
# ## Reviewing our Dataset
# ***

# %%
df.describe().T
# Out:
#                      count       mean        std  min    25%        50%  \
# I                   8675.0   0.769568   0.421134  0.0   1.00   1.000000
# J                   8675.0   0.395850   0.489061  0.0   0.00   0.000000
# N                   8675.0   0.862017   0.344902  0.0   1.00   1.000000
# T                   8675.0   0.458905   0.498337  0.0   0.00   0.000000
# NF                  8675.0   0.480346   0.499642  0.0   0.00   0.000000
# ...                    ...        ...        ...  ...    ...        ...
# avg_third_person    8675.0   0.415968   0.252414  0.0   0.24   0.361702
# positive_words      8675.0  39.527608  13.471651  0.0  30.00  40.000000
# avg_positive_words  8675.0   0.810456   0.262999  0.0   0.64   0.800000
# negative_words      8675.0  27.081960  10.352061  0.0  20.00  27.000000
# avg_negative_words  8675.0   0.554810   0.204013  0.0   0.42   0.540000
#
#                       75%         max
# I                    1.00    1.000000
# J                    1.00    1.000000
# N                    1.00    1.000000
# T                    1.00    1.000000
# NF                   1.00    1.000000
# ...                   ...         ...
# avg_third_person     0.54    3.120000
# positive_words      49.00  111.000000
# avg_positive_words   0.98    2.220000
# negative_words      34.00   78.000000
# avg_negative_words   0.68    1.714286
#
# [76 rows x 8 columns]

# %%
df.head()
# Out:
#    type                                              posts  I  J  N  T  NF  \
# 0  INFJ  'http://www.youtube.com/watch?v=qsXHcwe3krw|||...  1  1  1  0   1
# 1  ENTP  'I'm finding the lack of me in these posts ver...  0  0  1  1   0
# 2  INTP  'Good one  _____   https://www.youtube.com/wat...  1  0  1  1   0
# 3  INTJ  'Dear INTP,   I enjoyed our conversation the o...  1  1  1  1   0
# 4  ENTJ  'You're fired.|||That's another silly misconce...  0  1  1  1   0
#
#    NT  SP  SJ  ...  them_count their_count  theirs_count  themselves_count  \
# 0   0   0   0  ...           1           2             0                 0
# 1   1   0   0  ...           5           4             0                 1
# 2   1   0   0  ...           2           0             0                 0
# 3   1   0   0  ...           2           2             0                 0
# 4   1   0   0  ...           2           6             0                 1
#
#    total_third_person  avg_third_person  positive_words  avg_positive_words  \
# 0                   7              0.14              19                0.38
# 1                  20              0.40              38                0.76
# 2                   3              0.06              35                0.70
# 3                  15              0.30              23                0.46
# 4                  37              0.74              33                0.66
#
#    negative_words  avg_negative_words
# 0               9                0.18
# 1              24                0.48
# 2              18                0.36
# 3              19                0.38
# 4              29                0.58
#
# [5 rows x 79 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8675 entries, 0 to 8674
# Data columns (total 79 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   type                    8675 non-null   object
#  1   posts                   8675 non-null   object
#  2   I                       8675 non-null   int64
#  3   J                       8675 non-null   int64
#  4   N                       8675 non-null   int64
#  5   T                       8675 non-null   int64
#  6   NF                      8675 non-null   int64
#  7   NT                      8675 non-null   int64
#  8   SP                      8675 non-null   int64
#  9   SJ                      8675 non-null   int64
#  10  posts_len               8675 non-null   int64
#  11  posts_separated         8675 non-null   object
#  12  count_posts             8675 non-null   int64
#  13  avg_num_char_x_post     8675 non-null   float64
#  14  num_of_links            8675 non-null   int64
#  15  :D_count                8675 non-null   int64
#  16  ;D_count                8675 non-null   int64
#  17  :)_count                8675 non-null   int64
#  18  ;)_count                8675 non-null   int64
#  19  :(_count                8675 non-null   int64
#  20  xD_count                8675 non-null   int64
#  21  XD_count                8675 non-null   int64
#  22  total_emoticons         8675 non-null   int64
#  23  avg_emoticons_per_post  8675 non-null   float64
#  24  INFJ_mentions           8675 non-null   int64
#  25  ENTP_mentions           8675 non-null   int64
#  26  INTP_mentions           8675 non-null   int64
#  27  INTJ_mentions           8675 non-null   int64
#  28  ENTJ_mentions           8675 non-null   int64
#  29  ENFJ_mentions           8675 non-null   int64
#  30  INFP_mentions           8675 non-null   int64
#  31  ENFP_mentions           8675 non-null   int64
#  32  ISFP_mentions           8675 non-null   int64
#  33  ISTP_mentions           8675 non-null   int64
#  34  ISFJ_mentions           8675 non-null   int64
#  35  ISTJ_mentions           8675 non-null   int64
#  36  ESTP_mentions           8675 non-null   int64
#  37  ESFP_mentions           8675 non-null   int64
#  38  ESTJ_mentions           8675 non-null   int64
#  39  ESFJ_mentions           8675 non-null   int64
#  40  total_mentions          8675 non-null   int64
#  41  avg_mentions_per_post   8675 non-null   float64
#  42  I_count                 8675 non-null   int64
#  43  me_count                8675 non-null   int64
#  44  my_count                8675 non-null   int64
#  45  mine_count              8675 non-null   int64
#  46  myself_count            8675 non-null   int64
#  47  We_count                8675 non-null   int64
#  48  us_count                8675 non-null   int64
#  49  our_count               8675 non-null   int64
#  50  ourselves_count         8675 non-null   int64
#  51  total_first_person      8675 non-null   int64
#  52  avg_first_person        8675 non-null   float64
#  53  you_count               8675 non-null   int64
#  54  your_count              8675 non-null   int64
#  55  yours_count             8675 non-null   int64
#  56  yourself_count          8675 non-null   int64
#  57  yourselves_count        8675 non-null   int64
#  58  total_second_person     8675 non-null   int64
#  59  avg_second_person       8675 non-null   float64
#  60  he_count                8675 non-null   int64
#  61  him_count               8675 non-null   int64
#  62  his_count               8675 non-null   int64
#  63  himself_count           8675 non-null   int64
#  64  she_count               8675 non-null   int64
#  65  her_count               8675 non-null   int64
#  66  hers_count              8675 non-null   int64
#  67  herself_count           8675 non-null   int64
#  68  they_count              8675 non-null   int64
#  69  them_count              8675 non-null   int64
#  70  their_count             8675 non-null   int64
#  71  theirs_count            8675 non-null   int64
#  72  themselves_count        8675 non-null   int64
#  73  total_third_person      8675 non-null   int64
#  74  avg_third_person        8675 non-null   float64
#  75  positive_words          8675 non-null   int64
#  76  avg_positive_words      8675 non-null   float64
#  77  negative_words          8675 non-null   int64
#  78  avg_negative_words      8675 non-null   float64
# dtypes: float64(8), int64(68), object(3)
# memory usage: 5.3+ MB

# %% [markdown]
# <a id=drop></a>

# %% [markdown]
# <a id='drop'></a>

# %% [markdown]
# ## Dropping Columns
# ***

# %% [markdown]
# <br>
#
# **Note:** The number of columns at our disposal are too many for what we need (79), in the next lines of code we will drop some of the least relevant ones.
# We will strat by dropping the "text" columns, we might use them later for other analysis so we will keep them in a separate dataframe.

# %%
df_text = df[['type','posts','posts_separated']]

# %%
df_text.head() #
# Out:
#    type                                              posts  \
# 0  INFJ  'http://www.youtube.com/watch?v=qsXHcwe3krw|||...
# 1  ENTP  'I'm finding the lack of me in these posts ver...
# 2  INTP  'Good one  _____   https://www.youtube.com/wat...
# 3  INTJ  'Dear INTP,   I enjoyed our conversation the o...
# 4  ENTJ  'You're fired.|||That's another silly misconce...
#
#                                      posts_separated
# 0  ["'http://www.youtube.com/watch?v=qsXHcwe3krw"...
# 1  ["'I'm finding the lack of me in these posts v...
# 2  ["'Good one  _____   https://www.youtube.com/w...
# 3  ["'Dear INTP,   I enjoyed our conversation the...
# 4  ["'You're fired.", "That's another silly misco...

# %%
df.drop(['posts','posts_separated'], axis=1, inplace= True)

# %% [markdown]
# ### Mentions columns
#
# We will reduce the number of mentions columns, from having one for each type to having the number of self-referencing and references to other MBTI types

# %%
mention_columns = df.iloc[:,22:38].columns.values

# %%
new_columns = dict(zip(mention_columns, [re.sub(r'_.*$','',x) for x in mention_columns]))

# %%
df=df.rename(columns = new_columns)

# %%
mentions_others = []
for e,i in enumerate(df['type']):
    result = df.drop(i, axis=1).iloc[e,22:37].sum()
    mentions_others.append(result)

# %%
df.insert(loc=38, column='mentions_others', value=mentions_others)

# %%
df.insert(loc=38, column='self_mentions', value=(df['total_mentions']-df['mentions_others']))

# %%
# Let's check to see if our code worked well
df.iloc[:,38:41].head()
# Out:
#    self_mentions  mentions_others  total_mentions
# 0              2                6               8
# 1             10                9              19
# 2              1                3               4
# 3              2               10              12
# 4              4                1               5

# %%
# We create this global variable since we will need to refer to it several times
mbti_types = ['ENFJ', 'ENFP', 'ENTJ', 'ENTP', 'ESFJ', 'ESFP', 'ESTJ', 'ESTP', 'INFJ', 'INFP', 'INTJ', 'INTP', 'ISFJ', 'ISFP', 'ISTJ', 'ISTP']

# %%
# we can now drop the old columns
df.drop(mbti_types, axis=1, inplace=True)

# %%
# we can also drop the emoticons columns except the total and average
emoticons_list = [':D_count',';D_count', ':)_count', ';)_count', ':(_count', 'xD_count', 'XD_count']
df.drop(emoticons_list, axis=1, inplace=True)

# %%
# we have the 1st person, 2nd person, and 3rd person total columns, we can keep those and drop the rest
pronouns_list = ['I_count', 'me_count','my_count', 'mine_count', 'myself_count', 'We_count', 'us_count','our_count', 'ourselves_count',
                'you_count', 'your_count', 'yours_count','yourself_count', 'yourselves_count',
                'he_count', 'him_count', 'his_count','himself_count', 'she_count', 'her_count', 'hers_count', 'herself_count', 'they_count', 'them_count', 'their_count', 'theirs_count', 'themselves_count']
df.drop(pronouns_list, axis=1, inplace=True)

# %%
# we can also drop the 'posts_len' column since it is very dependent on the 'count_posts' column
df.drop('posts_len', axis=1, inplace=True)

# %% [markdown]
# ### Correcting some columns

# %%
# As we saw in the data wrangling section, it is best we take the average of the columns since for some people only a handful of posts were collected.
avg_links = df['num_of_links'] / df['count_posts']
df.insert(loc=df.columns.get_loc("num_of_links"), column='avg_links', value=avg_links)
df.drop('num_of_links', axis=1, inplace=True)

# %%
# we will do the same wiht the mentions columns
mentions_corrected = ['self_mentions', 'mentions_others','total_mentions']

for column in mentions_corrected:
    average = df[column] / df['count_posts']
    location = df.columns.get_loc(column)
    df.insert(loc=location, column='avg_'+column, value=average)
    df.drop(column, axis=1, inplace=True)

# %%
# we will drop other columns
drop_columns = ['count_posts','total_emoticons', 'total_first_person', 'total_second_person', 'total_third_person', 'positive_words', 'negative_words', 'avg_mentions_per_post']
df.drop(drop_columns, axis=1, inplace=True)

# %%
# let's check the number of remaining columns
len(df.columns)
# Out:
# 20

# %% [markdown]
# <a id=colors></a>

# %% [markdown]
# <br>
#
# ## Colors
# ***

# %% [markdown]
# We create lists of HEX, RGB, and % RGB colors to keep a homogeneous look across visualizations

# %%
colors_types = {'INFP':'#AD3139','INFJ':'#C64D43','INTP':'#D66C54','INTJ':'#E28C64','ENTP':'#E9AB72','ENFP':'#EEC58A','ISTP' : '#F2DDA3','ISFP' : '#F5EEBA','ENTJ' : '#F2F6D4','ISTJ' : '#E6F2F0','ENFJ' : '#CCE4EC','ISFJ' : '#B0D3DF','ESTP' : '#91BACF','ESFP' : '#769EBE','ESFJ' : '#5C80AC','ESTJ' : '#4A619A'}
colors_main = {'I':'#a50026','E':'#d73027','S':'#f46d43','N':'#fdae61','T':'#fee090','F':'#ffffbf','P':'#e0f3f8','J':'#abd9e9'}
colors_keirsey = {'NF':'#a50026', 'NT':'#fdae61' ,'SP':'#abd9e9', 'SJ':'#313695'}

# %%
def hex_rgb_converter(dictionary, dictionary_name):
    dictionary_name = {}
    for k, v in dictionary.items():
        v = v.lstrip('#')  
        result = tuple(int(v[i:i+2], 16) for i in (0, 2, 4))
        dictionary_name[k] = result
    return dictionary_name

# %%
colors_main_rgb = hex_rgb_converter(colors_main, 'colors_main_rgb')
colors_types_rgb = hex_rgb_converter(colors_types, 'colors_type_rgb')
colors_keirsey_rgb = hex_rgb_converter(colors_keirsey, 'colors_keirsey_rgb')

# %%
def rgb_pct_converter(dictionary, dictionary_name):
        dictionary_name = {}
        for k, v in dictionary.items():
            result = [x/255 for x in v]
            result.append(1.0)
            dictionary_name[k] = result
        return dictionary_name

# %%
colors_main_rgb_pct = rgb_pct_converter(colors_main_rgb, 'colors_main_rgb_pct')
colors_types_rgb_pct = rgb_pct_converter(colors_types_rgb, 'colors_types_rgb_pct')
colors_keirsey_rgb_pct = rgb_pct_converter(colors_keirsey_rgb, 'colors_keirsey_rgb_pct')

# %% [markdown]
# <a id=visuals></a>

# %% [markdown]
# <br>
#
# ## Visuals
#
# ***

# %% [markdown]
# ### The 16 MBTI Types

# %%
df_cat = df.select_dtypes(include='object').copy()
df_cat.type.value_counts()
# Out:
# INFP    1832
# INFJ    1470
# INTP    1304
# INTJ    1091
# ENTP     685
# ENFP     675
# ISTP     337
# ISFP     271
# ENTJ     231
# ISTJ     205
# ENFJ     190
# ISFJ     166
# ESTP      89
# ESFP      48
# ESFJ      42
# ESTJ      39
# Name: type, dtype: int64

# %%
# Let's first save the order of the previous visualization to avoid mismatching mbti types
sorter = df_cat['type'].value_counts().index.to_list()

# %%
# We import another dataset with data we scrapped from 16personalities to compare our data with the one from the general population
df_global = pd.read_csv('../../data/16personalities.csv')

# %%
# Let's check how it looks like
df_global.head()
# Out:
#    code  percentage
# 0  enfj    0.074567
# 1  enfp    0.144600
# 2  entj    0.024050
# 3  entp    0.044300
# 4  esfj    0.090000

# %%
# We convert the code (which is the MBTI type) to uppercase letters
df_global['code'] = df_global['code'].apply(lambda x:x.upper())

# %%
# Create the dictionary that defines the order for sorting
sorterIndex = dict(zip(sorter,range(len(sorter))))

# Generate a rank column that will be used to sort the dataframe numerically
df_global['Rank'] = df_global['code'].map(sorterIndex)

# Sort the dataframe
df_global.sort_values('Rank', ascending = True, inplace = True)

# %%
# We can look at the new dataframe with the ranking column
df_global
# Out:
#     code  percentage  Rank
# 9   INFP    0.156667     0
# 8   INFJ    0.079200     1
# 11  INTP    0.055067     2
# 10  INTJ    0.031433     3
# 3   ENTP    0.044300     4
# 1   ENFP    0.144600     5
# 15  ISTP    0.020900     6
# 13  ISFP    0.054967     7
# 2   ENTJ    0.024050     8
# 14  ISTJ    0.031450     9
# 0   ENFJ    0.074567    10
# 12  ISFJ    0.079250    11
# 7   ESTP    0.021217    12
# 5   ESFP    0.052683    13
# 4   ESFJ    0.090000    14
# 6   ESTJ    0.034917    15

# %%
fig, ax = plt.subplots(figsize=(12,6))

# Countplot
sns.countplot(x='type', data=df_cat, order= df_cat['type'].value_counts().index, palette='RdYlBu', ax=ax)
plt.ylabel('Number of observations in dataset', labelpad=20)
plt.xlabel('MBTI Type',labelpad=20)

# Scatterplot Data
x = df_global['code'].to_list()
y = np.array(df_global['percentage']*100)

# Scatterplot
ax2 = ax.twinx()
sns.scatterplot(x, y, ax=ax2,  s=70, facecolors='grey', edgecolors='b', linewidth=1.5)
ax2.set_xticklabels(x)
ax2.grid(False)
ax2.yaxis.set_major_formatter(mtick.PercentFormatter())
ax2.set_ylabel('% Estimate of MBTI in global population', rotation=270, labelpad=20)

# Legend
bars = Patch(color='gray', label='Dataset Observations')
dots = matplotlib.lines.Line2D([], [], color='gray', marker='o', linestyle='None', markersize=5, label='Study Population Distribution')
plt.legend(handles=[bars, dots], loc='best', bbox_to_anchor=(0.45, 0.45, 0.5, 0.5))

plt.title('Comparison sample from Personality Cafe & study population estimate from 16Personalities',size=15,pad=20)
plt.figtext(.5,.88,'(Note: only English speaking countries were taken into consideration)',fontsize=10,ha='center')
plt.savefig('Figures/countplot_types_comparison_population.png', dpi=300)

plt.show()
# Out:
# <ipython-input-37-66ecd8af186f>:15: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_xticklabels(x)

# %% [markdown]
# <br>
#
# **We can see that there are quite a lot more cases of Intuition (N) than Sensing (S) and in the first category, Introversion (I) has more cases than Extraversion (E). We can see there is quite a big difference between our data an the target population... this is something to consider later on.**

# %% [markdown]
# <a id=heatmap></a>

# %% [markdown]
# <br>
#
# ### Heatmap
# ***

# %% [markdown]
# There are many variables in our dataset that are similar amongst them. We will focus on 5 variables:
# - Average number of characters per post
# - Number of links
# - How many times the reference their own MBTI type (self mentions)
# - Total number of emojis they use

# %%
df_heatmap = df.set_index('type')

# %%
# We standardize the columns 
df_norm_col=(df_heatmap-df_heatmap.mean())/df_heatmap.std()

# %%
# There are fields that really do not add a lot of value because they are clearly correlated with the target label, we will drop them. We will also drop the total columns and keep only the averages.
drop = ['I','J','N','T','NT','NF','SP','SJ']

# %%
df_heatmap.columns
# Out:
# Index(['I', 'J', 'N', 'T', 'NF', 'NT', 'SP', 'SJ', 'avg_num_char_x_post',
#        'avg_links', 'avg_emoticons_per_post', 'avg_self_mentions',
#        'avg_mentions_others', 'avg_total_mentions', 'avg_first_person',
#        'avg_second_person', 'avg_third_person', 'avg_positive_words',
#        'avg_negative_words'],
#       dtype='object')

# %%
plt.figure(figsize=(15,10))
           
ax = sns.heatmap(df_norm_col.drop(drop, axis=1).groupby('type').mean(), cmap='RdYlBu_r', linewidths=0.5, annot=True)

plt.ylabel('MBTI Types', labelpad=20)
plt.yticks(rotation = 0)
plt.title('Heatmap of MBTI Types and parameters (average)', size=15, pad=20)

plt.tight_layout()
plt.savefig('Figures/Heatmap_target.png', dpi=300)

plt.show()

# %% [markdown]
# <a id=characters></a>

# %% [markdown]
# <br>
#
# ### Avg. Number of characters per post
# ***

# %%
plt.figure(figsize=(14,8))

sns.set_palette(sns.color_palette(list(colors_types.values())))
sns.boxplot(x='type',y='avg_num_char_x_post', data=df, order=sorter, showmeans=True, meanprops={"marker":"s","markerfacecolor":"white", "markeredgecolor":"grey"})
#sns.swarmplot(x='type', y="avg_num_char_x_post", data=df, color='k', alpha=0.3, order=sorter)

plt.title('Average Number of Characters per post separated by MBTI type', size=15, pad=20)
plt.xlabel('MBTI Type', labelpad=20)
plt.ylabel('Avg. number of characters per post', labelpad=20)

plt.savefig('Figures/Boxplot_Num_Characters_types.png', dpi=300)

plt.show()

# %% [markdown]
# **Test for Normality**

# %%
fig, ax = plt.subplots(figsize=(10, 6))
ax.hist(df.avg_num_char_x_post, density=False, bins=20)
ax.axes.get_yaxis().set_visible(False)

for rect in ax.patches:
    height = rect.get_height()
    ax.annotate(f'{int(height)}', xy=(rect.get_x()+rect.get_width()/2, height), 
                xytext=(0, 5), textcoords='offset points', ha='center', va='bottom')
plt.title('Variable Distribution', pad = 15, size = 15)
plt.show()

# %% [markdown]
# **Kruskal-Wallis Test by Ranks**

# %%
list_array = []

for mtype in mbti_types:
    
    result = df[df['type'] == mtype]['avg_num_char_x_post']
    list_array.append(result)
    
H, pval = stats.kruskal(list_array[0],list_array[1],list_array[2],list_array[3],
                       list_array[4],list_array[5],list_array[6],list_array[7],
                       list_array[8],list_array[9],list_array[10],list_array[11],
                       list_array[12],list_array[13],list_array[14],list_array[15])
    
print("H-statistic:", H)
print("P-Value:", pval)

if pval < 0.05:
    print("Reject NULL hypothesis - Significant differences exist between groups.")
if pval > 0.05:
    print("Accept NULL hypothesis - No significant difference between groups.")
# Out:
# H-statistic: 135.6341838645423
# P-Value: 1.6673085613521744e-21
# Reject NULL hypothesis - Significant differences exist between groups.

# %% [markdown]
# https://stats.stackexchange.com/questions/79289/why-is-statistically-significant-not-enough/79304#79304

# %% [markdown]
# **Post hoc Dunn's Adjustment**

# %%
import scikit_posthocs as sp
dunn = sp.posthoc_dunn(list_array, p_adjust='bonferroni', sort=False)

# %%
dunn.columns = mbti_types
dunn['types'] = mbti_types
dunn = dunn.set_index('types')

# %%
def color_dunn(val):
    if val < 0.05 and val != -1:
        color = 'lightgreen'
        return 'background-color: %s' % color
    else:
        color = None
        return 'background-color: %s' % color

# %%
#dunn = dunn.mask(np.triu(np.ones(dunn.shape, dtype=np.bool_)))

dunn = dunn.round(4)
dunn.style.set_precision(4).applymap(color_dunn)
# Out:
# <style  type="text/css" >
# #T_6092cb96_27af_11eb_832e_acde48001122row0_col0,#T_6092cb96_27af_11eb_832e_acde48001122row0_col1,#T_6092cb96_27af_11eb_832e_acde48001122row0_col2,#T_6092cb96_27af_11eb_832e_acde48001122row0_col4,#T_6092cb96_27af_11eb_832e_acde48001122row0_col6,#T_6092cb96_27af_11eb_832e_acde48001122row0_col8,#T_6092cb96_27af_11eb_832e_acde48001122row0_col9,#T_6092cb96_27af_11eb_832e_acde48001122row0_col10,#T_6092cb96_27af_11eb_832e_acde48001122row0_col11,#T_6092cb96_27af_11eb_832e_acde48001122row0_col12,#T_6092cb96_27af_11eb_832e_acde48001122row0_col14,#T_6092cb96_27af_11e
row4_col11,#T_6092cb96_27af_11eb_832e_acde48001122row4_col12,#T_6092cb96_27af_11eb_832e_acde48001122row4_col13,#T_6092cb96_27af_11eb_832e_acde48001122row4_col14,#T_6092cb96_27af_11eb_832e_acde48001122row4_col15,#T_6092cb96_27af_11eb_832e_acde48001122row5_col1,#T_6092cb96_27af_11eb_832e_acde48001122row5_col2,#T_6092cb96_27af_11eb_832e_acde48001122row5_col3,#T_6092cb96_27af_11eb_832e_acde48001122row5_col4,#T_6092cb96_27af_11eb_832e_acde48001122row5_col5,#T_6092cb96_27af_11eb_832e_acde48001122row5_col6,#T_6092cb96_27af_11eb_832e_acde48001122row5_col7,#T_6092cb96_27af_11eb_832e_acde48001122row5_col9,#T_6092cb96_27af_11eb_832e_acde48001122row5_col10,#T_6092cb96_27af_11eb_832e_acde48001122row5_col11,#T_6092cb96_27af_11eb_832e_acde48001122row5_col12,#T_6092cb96_27af_11eb_832e_acde48001122row5_col13,#T_6092cb96_27af_11eb_832e_acde48001122row5_col14,#T_6092cb96_27af_11eb_832e_acde48001122row5_col15 ...

# %% [markdown]
# [Dunn Interpretation](https://stats.stackexchange.com/questions/126686/how-to-read-the-results-of-dunns-test)

# %% [markdown]
# **Effect Size with Hedges' g**

# %%
mean = np.mean(df.avg_num_char_x_post)
std = np.std(df.avg_num_char_x_post)
print(mean)
print(std)
# Out:
# 145.46464059537522
# 28.866481389886747

# %%
dictionary = {}

for mtype in mbti_types:
    count = len(df[df['type'] == mtype]['avg_num_char_x_post'])
    mean = np.mean(df[df['type'] == mtype]['avg_num_char_x_post'])
    std = np.std(df[df['type'] == mtype]['avg_num_char_x_post'])
    dictionary[mtype] = [count, mean, std]

# %%
hedges = pd.DataFrame(dictionary).T

# %%
hedges.columns = ['Count', 'Mean', 'Std']

# %%
hedges.head(3)
# Out:
#       Count        Mean        Std
# ENFJ  190.0  149.979981  29.180304
# ENFP  675.0  147.890711  26.873478
# ENTJ  231.0  145.113648  26.082768

# %% [markdown]
# [Pooled Standard Deviation](http://goldbook.iupac.org/terms/view/P04758)

# %%
items = []

for i in hedges.iterrows():
    
    result = ((i[1][0]-1)*(i[1][2]**2))
    items.append(result)

pooled_std = np.sqrt((sum(items)) / (hedges.Count.sum() - len(hedges.Count)))
pooled_std
# Out:
# 28.64869151212286

# %%
items = []

for i in hedges.iterrows():
    result = i[1][0]*i[1][1]
    items.append(result)

pooled_mean = sum(items) / (hedges.Count.sum())
pooled_mean
# Out:
# 145.4646405953752

# %%
hedges['hedges_g'] = list(map(lambda x : round((x - pooled_mean)/pooled_std,2), hedges['Mean']))

# %%
def color_rgy(val):
    if val > 0.8 or val < -0.8:
        color = 'red'
        return 'background-color: %s' % color
    elif val > 0.5 or val < -0.5:
        color = 'orange'
        return 'background-color: %s' % color
    elif val > 0.2 or val < -0.2:
        color = 'lightgreen'
        return 'background-color: %s' % color
    else:
        color = None
        return 'background-color: %s' % color

# %%
hedges
hedges.style.applymap(color_rgy, subset=pd.IndexSlice['hedges_g'])
# Out:
# <style  type="text/css" >
# #T_60b3a5e6_27af_11eb_832e_acde48001122row0_col3,#T_60b3a5e6_27af_11eb_832e_acde48001122row1_col3,#T_60b3a5e6_27af_11eb_832e_acde48001122row2_col3,#T_60b3a5e6_27af_11eb_832e_acde48001122row3_col3,#T_60b3a5e6_27af_11eb_832e_acde48001122row4_col3,#T_60b3a5e6_27af_11eb_832e_acde48001122row6_col3,#T_60b3a5e6_27af_11eb_832e_acde48001122row8_col3,#T_60b3a5e6_27af_11eb_832e_acde48001122row9_col3,#T_60b3a5e6_27af_11eb_832e_acde48001122row10_col3,#T_60b3a5e6_27af_11eb_832e_acde48001122row11_col3,#T_60b3a5e6_27af_11eb_832e_acde48001122row12_col3,#T_60b3a5e6_27af_11eb_832e_acde48001122row14_col3{
#             background-color:  None;
#         }#T_60b3a5e6_27af_11eb_832e_acde48001122row5_col3{
#             background-color:  orange;
#         }#T_60b3a5e6_27af_11eb_832e_acde48001122row7_col3,#T_60b3a5e6_27af_11eb_832e_acde48001122row13_col3,#T_60b3a5e6_27af_11eb_832e_acde48001122row15_col3{
#             background-color:  lightgreen;
#         }</style><table id="T_60b3a5e6_27af_11eb_832e_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Count</th>        <th class="col_heading level0 col1" >Mean</th>        <th class="col_heading level0 col2" >Std</th>        <th class="col_heading level0 col3" >hedges_g</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_60b3a5e6_27af_11eb_832e_acde48001122level0_row0" class="row_heading level0 row0" >ENFJ</th>
#                         <td id="T_60b3a5e6_27af_11eb_832e_acde48001122row0_col0" class="data row0 col0" >190.000000</td>
#                         <td id="T_60b3a5e6_27af_11eb_832e_acde48001122row0_col1" class="data row0 col1" >149.979981</td>
#                         <td id="T_60b3a5e6_27af_11eb_832e_acde48001122row0_col2" class="data row0 col2" >29.180304</td>
#                         <td id="T_60b3a5e6_27af_11eb_832e_acde48001122row0_col3" class="data row0 col3" >0.160000</td>
#             </tr>
#             <tr>
#                         <th id="T_60b3a5e6_27af_11eb_832e_acde48001122level0_row1" class="row_heading level0 row1" >ENFP</th>
#                         <td id="T_60b3a5e6_27af_11eb_832e_acde48001122row1_col0" class="data row1 col0" >675.000000</td>
#                         <td id="T_60b3a5e6_27af_11eb_832e_acde48001122row1_col1" class="data row1 col1" >147.890711</td>
#                         <td id="T_60b3a5e6_27af_11eb_832e_acde48001122row1_col2" class="data row1 col2" >26.873478</td>
#                         <td id="T_60b3a5e6_27af_11eb_832e_acde48001122row1_col3" class="data row1 col3" >0.080000</td>
#             </tr>
#             <tr>
#                         <th id="T_60b3a5e6_27af_11eb_832e_acde48001122level0_row2" class="row_heading level0 row2" >ENTJ</th>
#                         <td id="T_60b3a5e6_27af_11eb_832e_acde48001122row2_col0" class="data row2 col0" >231.000000</td>
#                         <td id="T_60b3a5e6_27af_11eb_832e_acde48001122row2_col1" class="data row2 col1" >145.113648</td>
#                         <td id="T_60b3a5e6_27af_11eb_832e_acde48001122row2_col2" class="data row2 col2" >26.082768</td>
#                         <td id="T_60b3a5e6_27af_11eb_832e_acde48001122row2_col3" class="data row2 col3" >-0.010000</td>
#             </tr>
#             <tr>
#                         <th id="T_60b3a5e6_27af_11eb_832e_acde48001122level0_row3" class="row_heading level0 row3" >ENTP</th>
#                         <td id="T_60b3a5e6_27af_11eb_832e_acde48001122row3_col0" class="data row3 col0" >685.000000</td>
#                         <td id="T_60b3a5e6_27af_11eb_832e_acde48001122row3_col1" class="data row3 col1" >141.686371</td>
#                         <td id="T_60b3a5e6_27af_11eb_832e_acde48001122row3_col2" class="data row3 col2" >28.684845</td>
#                         <td id="T_60b3a5e6_27af_11eb_832e_acde48001122row3_col3" class="data row3 col3" >-0.130000</td>
#             </tr>
#             <tr>
#                         <th id="T_60b3a5e6_27af_11eb_832e_acde48001122level0_row4" class="row_heading level0 row4" >ESFJ</th>
#                         <td id="T_60b3a5e6_27af_11eb_832e_acde48001122row4_col0" class="data row4 col0" >42.000000</td>
#                         <td id="T_60b3a5e6_27af_11eb_832e_acde48001122row4_col1" class="data row4 col1" >150.274701</td>
#                         <td id="T_60b3a5e6_27af_11eb_832e_acde48001122row4_col2" class="data row4 col2" >33.550198</td>
#                         <td id="T_60b3a5e6_27af_11eb_832e_acde48001122row4_col3" class="data row4 col3" >0.170000</td>
#             </tr>
#             <tr>
#                         <th id="T_60b3a5e6_27af_11eb_832e_acde48001122level0_row5" class="row_heading level0 row5" >ESFP</th>
#                         <td id="T_60b3a5e6_27af_11eb_832e_acde48001122row5_col0" class="data row5 col0" >48.000000</td>
#                         <td id="T_60b3a5e6_27af_11eb_832e_acde48001122row5_col1" class="data row5 col1" >128.240393</td>
#                         <td id="T_60b3a5e6_27af_11eb_832e_acde48001122row5_col2" class="data row5 col2" >36.664127</td>
#                         <td id="T_60b3a5e6_27af_11eb_832e_acde48001122row5_col3" class="data row5 col3" >-0.600000</td>
#             </tr>
#             <tr>
#                         <th id="T_60b3a5e6_27af_11eb_832e_acde48001122level0_row6" class="row_heading level0 row6" >ESTJ</th>
#                         <td id="T_60b3a5e6_27af_11eb_832e_acde48001122row6_col0" class="data row6 col0" >39.000000</td>
#                         <td id="T_60b3a5e6_27af_11eb_832e_acde48001122row6_col1" class="data row6 col1" >142.004465</td>
#                         <td id="T_60b3a5e6_27af_11eb_832e_acde48001122row6_col2" class="data row6 col2" >25.775793</td>
#                         <td id="T_60b3a5e6_27af_11eb_832e_acde48001122row6_col3" class="data row6 col3" >-0.120000</td>
#             </tr>
#             <tr>
#                         <th id="T_60b3a5e6_27af_11eb_832e_acde48001122level0_row7" class="row_heading level0 row7" >ESTP</th>
#                         <td id="T_60b3a5e6_27af_11eb_832e_acde48001122row7_col0" class="data row7 col0" >89.000000</td>
#                         <td id="T_60b3a5e6_27af_11eb_832e_acde48001122row7_col1" class="data row7 col1" >136.280449</td>
#                         <td id="T_60b3a5e6_27af_11eb_832e_acde48001122row7_col2" class="data row7 col2" >27.408907</td>
#                         <td id="T_60b3a5e6_27af_11eb_832e_acde48001122row7_col3" class="data row7 col3" >-0.320000</td>
#             </tr>
#             <tr>
#                         <th id="T_60b3a5e6_27af_11eb_832e_acde48001122level0_row8" class="row_heading level0 row8" >INFJ</th>
#                         <td id="T_60b3a5e6_27af_11eb_832e_acde48001122row8_col0" class="data row8 col0" >1470.000000</td>
#                         <td id="T_60b3a5e6_27af_11eb_832e_acde48001122row8_col1" class="data row8 col1" >150.098757</td>
#                         <td id="T_60b3a5e6_27af_11eb_832e_acde48001122row8_col2" class="data row8 col2" >28.240643</td>
#                         <td id="T_60b3a5e6_27af_11eb_832e_acde48001122row8_col3" class="data row8 col3" >0.160000</td>
#             </tr>
#             <tr>
#                         <th id="T_60b3a5e6_27af_11eb_832e_acde48001122level0_row9" class="row_heading level0 row9" >INFP</th>
#                         <td id="T_60b3a5e6_27af_11eb_832e_acde48001122row9_col0" class="data row9 col0" >1832.000000</td>
#                         <td id="T_60b3a5e6_27af_11eb_832e_acde48001122row9_col1" class="data row9 col1" >146.307324</td>
#                         <td id="T_60b3a5e6_27af_11eb_832e_acde48001122row9_col2" class="data row9 col2" >28.978885</td>
#                         <td id="T_60b3a5e6_27af_11eb_832e_acde48001122row9_col3" class="data row9 col3" >0.030000</td>
#             </tr>
#             <tr>
#                         <th id="T_60b3a5e6_27af_11eb_832e_acde48001122level0_row10" class="row_heading level0 row10" >INTJ</th>
#                         <td id="T_60b3a5e6_27af_11eb_832e_acde48001122row10_col0" class="data row10 col0

# %% [markdown]
# <a id=links></a>

# %% [markdown]
# <br>
# <br>
#
# ### Number of Links
#
# ***

# %%
plt.figure(figsize=(14,8))

sns.set_palette(sns.color_palette(list(colors_types.values())))
sns.boxplot(x='type',y='avg_links', data=df, order=sorter, showfliers=False, showmeans=True, meanprops={"marker":"s","markerfacecolor":"white", "markeredgecolor":"grey"})

plt.title('Number of Links by MBTI type', size=15, pad=20)
plt.xlabel('MBTI Type', labelpad=20)
plt.ylabel('Average number of links per post', labelpad=20)

plt.savefig('Figures/Boxplot_Num_Links_types.png', dpi=300)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 6))
ax.hist(df.avg_links, density=False, bins=20)
ax.axes.get_yaxis().set_visible(False)

for rect in ax.patches:
    height = rect.get_height()
    ax.annotate(f'{int(height)}', xy=(rect.get_x()+rect.get_width()/2, height), 
                xytext=(0, 5), textcoords='offset points', ha='center', va='bottom')
    
plt.title('Variable Distribution', pad = 15, size = 15)
plt.show()

# %%
list_array = []

for mtype in mbti_types:
    
    result = df[df['type'] == mtype]['avg_links']
    list_array.append(result)
    
H, pval = stats.kruskal(list_array[0],list_array[1],list_array[2],list_array[3],
                       list_array[4],list_array[5],list_array[6],list_array[7],
                       list_array[8],list_array[9],list_array[10],list_array[11],
                       list_array[12],list_array[13],list_array[14],list_array[15])
    
print("H-statistic:", H)
print("P-Value:", pval)

if pval < 0.05:
    print("Reject NULL hypothesis - Significant differences exist between groups.")
if pval > 0.05:
    print("Accept NULL hypothesis - No significant difference between groups.")
# Out:
# H-statistic: 83.09387036583148
# P-Value: 1.8901763836772887e-11
# Reject NULL hypothesis - Significant differences exist between groups.

# %% [markdown]
# **Post hoc Dunn's Adjustment**

# %%
dunn = sp.posthoc_dunn(list_array, p_adjust='bonferroni', sort=False)

# %%
dunn.columns = mbti_types
dunn['types'] = mbti_types
dunn = dunn.set_index('types')

# %%
def color_dunn(val):
    if val < 0.05 and val != -1:
        color = 'lightgreen'
        return 'background-color: %s' % color
    else:
        color = None
        return 'background-color: %s' % color

# %%
dunn = dunn.round(4)
dunn.style.set_precision(4).applymap(color_dunn)
# Out:
# <style  type="text/css" >
# #T_62e32756_27af_11eb_832e_acde48001122row0_col0,#T_62e32756_27af_11eb_832e_acde48001122row0_col1,#T_62e32756_27af_11eb_832e_acde48001122row0_col2,#T_62e32756_27af_11eb_832e_acde48001122row0_col3,#T_62e32756_27af_11eb_832e_acde48001122row0_col4,#T_62e32756_27af_11eb_832e_acde48001122row0_col5,#T_62e32756_27af_11eb_832e_acde48001122row0_col6,#T_62e32756_27af_11eb_832e_acde48001122row0_col7,#T_62e32756_27af_11eb_832e_acde48001122row0_col8,#T_62e32756_27af_11eb_832e_acde48001122row0_col9,#T_62e32756_27af_11eb_832e_acde48001122row0_col10,#T_62e32756_27af_11eb_832e_acde48001122row0_col11,#T_62e32756_27af_11eb_832e_acde48001122row0_col12,#T_62e32756_27af_11eb_832e_acde48001122row0_col14,#T_62e32756_27af_11eb_832e_acde48001122row0_col15,#T_62e32756_27af_11eb_832e_acde48001122row1_col0,#T_62e32756_27af_11eb_832e_acde48001122row1_col1,#T_62e32756_27af_11eb_832e_acde48001122row1_col2,#T_62e32756_27af_11eb_832e_acde48001122row1_col3,#T_62e32756_27af_11eb_832e_acde48001122row1_col4,#T_62e32756_27af_11eb_832e_acde48001122row1_col5,#T_62e32756_27af_11eb_832e_acde48001122row1_col6,#T_62e32756_27af_11eb_832e_acde48001122row1_col7,#T_62e32756_27af_11eb_832e_acde48001122row1_col8,#T_62e32756_27af_11eb_832e_acde48001122row1_col10,#T_62e32756_27af_11eb_832e_acde48001122row1_col12,#T_62e32756_27af_11eb_832e_acde48001122row1_col14,#T_62e32756_27af_11eb_832e_acde48001122row1_col15,#T_62e32756_27af_11eb_832e_acde48001122row2_col0,#T_62e32756_27af_11eb_832e_acde48001122row2_col1,#T_62e32756_27af_11eb_832e_acde48001122row2_col2,#T_62e32756_27af_11eb_832e_acde48001122row2_col3,#T_62e32756_27af_11eb_832e_acde48001122row2_col4,#T_62e32756_27af_11eb_832e_acde48001122row2_col5,#T_62e32756_27af_11eb_832e_acde48001122row2_col6,#T_62e32756_27af_11eb_832e_acde48001122row2_col7,#T_62e32756_27af_11eb_832e_acde48001122row2_col8,#T_62e32756_27af_11eb_832e_acde48001122row2_col9
# ENFJ: Count = 190, Mean = 0.05, Std = 0.1
# ENFP: Count = 675, Mean = 0.05, Std = 0.09
# ENTJ: Count = 231, Mean = 0.05, Std = 0.08
# ENTP: Count = 685, Mean = 0.05, Std = 0.08
# ESFJ: Count = 42, Mean = 0.03, Std = 0.05
# ESFP: Count = 48, Mean = 0.06, Std = 0.11
# ESTJ: Count = 39, Mean = 0.05, Std = 0.13
# ESTP: Count = 89, Mean = 0.07, Std = 0.13
# INFJ: Count = 1470, Mean = 0.07, Std = 0.12
# INFP: Count = 1832, Mean = 0.08, Std = 0.12
# INTJ: Count = 1091, Mean = 0.07, Std = 0.12
# INTP: Count = 1304, Mean = 0.07, Std = 0.12
# ISFJ: Count = 166, Mean = 0.07, Std = 0.14
# ISFP: Count = 271, Mean = 0.09, Std = 0.14
# ISTJ: Count = 205, Mean = 0.06, Std = 0.11
# ISTP: Count = 337, Mean = 0.08, Std = 0.15

# %%
hedges = pd.DataFrame(dictionary).T

# %%
hedges.columns = ['Count', 'Mean', 'Std']

# %%
hedges.head(3)
# Out:
#       Count      Mean       Std
# ENFJ  190.0  0.053700  0.101253
# ENFP  675.0  0.051617  0.087344
# ENTJ  231.0  0.054410  0.084802

# %% [markdown]
# [Pooled Standard Deviation](http://goldbook.iupac.org/terms/view/P04758)

# %%
items = []

for i in hedges.iterrows():
    
    result = ((i[1][0]-1)*(i[1][2]**2))
    items.append(result)

pooled_std = np.sqrt((sum(items)) / (hedges.Count.sum() - len(hedges.Count)))
pooled_std
# Out:
# 0.11677298276990034

# %%
items = []

for i in hedges.iterrows():
    result = i[1][0]*i[1][1]
    items.append(result)

pooled_mean = sum(items) / (hedges.Count.sum())
pooled_mean
# Out:
# 0.06749841819593672

# %%
hedges['hedges_g'] = list(map(lambda x : round((x - pooled_mean)/pooled_std,2), hedges['Mean']))

# %%
hedges
hedges.style.applymap(color_rgy, subset=pd.IndexSlice['hedges_g'])
# Out:
# <style  type="text/css" >
# #T_632bb80e_27af_11eb_832e_acde48001122row0_col3,#T_632bb80e_27af_11eb_832e_acde48001122row1_col3,#T_632bb80e_27af_11eb_832e_acde48001122row2_col3,#T_632bb80e_27af_11eb_832e_acde48001122row3_col3,#T_632bb80e_27af_11eb_832e_acde48001122row5_col3,#T_632bb80e_27af_11eb_832e_acde48001122row6_col3,#T_632bb80e_27af_11eb_832e_acde48001122row7_col3,#T_632bb80e_27af_11eb_832e_acde48001122row8_col3,#T_632bb80e_27af_11eb_832e_acde48001122row9_col3,#T_632bb80e_27af_11eb_832e_acde48001122row10_col3,#T_632bb80e_27af_11eb_832e_acde48001122row11_col3,#T_632bb80e_27af_11eb_832e_acde48001122row12_col3,#T_632bb80e_27af_11eb_832e_acde48001122row13_col3,#T_632bb80e_27af_11eb_832e_acde48001122row14_col3,#T_632bb80e_27af_11eb_832e_acde48001122row15_col3{
#             background-color:  None;
#         }#T_632bb80e_27af_11eb_832e_acde48001122row4_col3{
#             background-color:  lightgreen;
#         }</style><table id="T_632bb80e_27af_11eb_832e_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Count</th>        <th class="col_heading level0 col1" >Mean</th>        <th class="col_heading level0 col2" >Std</th>        <th class="col_heading level0 col3" >hedges_g</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_632bb80e_27af_11eb_832e_acde48001122level0_row0" class="row_heading level0 row0" >ENFJ</th>
#                         <td id="T_632bb80e_27af_11eb_832e_acde48001122row0_col0" class="data row0 col0" >190.000000</td>
#                         <td id="T_632bb80e_27af_11eb_832e_acde48001122row0_col1" class="data row0 col1" >0.053700</td>
#                         <td id="T_632bb80e_27af_11eb_832e_acde48001122row0_col2" class="data row0 col2" >0.101253</td>
#                         <td id="T_632bb80e_27af_11eb_832e_acde48001122row0_col3" class="data row0 col3" >-0.120000</td>
#             </tr>
#             <tr>
#                         <th id="T_632bb80e_27af_11eb_832e_acde48001122level0_row1" class="row_heading level0 row1" >ENFP</th>
#                         <td id="T_632bb80e_27af_11eb_832e_acde48001122row1_col0" class="data row1 col0" >675.000000</td>
#                         <td id="T_632bb80e_27af_11eb_832e_acde48001122row1_col1" class="data row1 col1" >0.051617</td>
#                         <td id="T_632bb80e_27af_11eb_832e_acde48001122row1_col2" class="data row1 col2" >0.087344</td>
#                         <td id="T_632bb80e_27af_11eb_832e_acde48001122row1_col3" class="data row1 col3" >-0.140000</td>
#             </tr>
#             <tr>
#                         <th id="T_632bb80e_27af_11eb_832e_acde48001122level0_row2" class="row_heading level0 row2" >ENTJ</th>
#                         <td id="T_632bb80e_27af_11eb_832e_acde48001122row2_col0" class="data row2 col0" >231.000000</td>
#                         <td id="T_632bb80e_27af_11eb_832e_acde48001122row2_col1" class="data row2 col1" >0.054410</td>
#                         <td id="T_632bb80e_27af_11eb_832e_acde48001122row2_col2" class="data row2 col2" >0.084802</td>
#                         <td id="T_632bb80e_27af_11eb_832e_acde48001122row2_col3" class="data row2 col3" >-0.110000</td>
#             </tr>
#             <tr>
#                         <th id="T_632bb80e_27af_11eb_832e_acde48001122level0_row3" class="row_heading level0 row3" >ENTP</th>
#                         <td id="T_632bb80e_27af_11eb_832e_acde48001122row3_col0" class="data row3 col0" >685.000000</td>
#                         <td id="T_632bb80e_27af_11eb_832e_acde48001122row3_col1" class="data row3 col1" >0.048719</td>
#                         <td id="T_632bb80e_27af_11eb_832e_acde48001122row3_col2" class="data row3 col2" >0.077758</td>
#                         <td id="T_632bb80e_27af_11eb_832e_acde48001122row3_col3" class="data row3 col3" >-0.160000</td>
#             </tr>
#             <tr>
#                         <th id="T_632bb80e_27af_11eb_832e_acde48001122level0_row4" class="row_heading level0 row4" >ESFJ</th>
#                         <td id="T_632bb80e_27af_11eb_832e_acde48001122row4_col0" class="data row4 col0" >42.000000</td>
#                         <td id="T_632bb80e_27af_11eb_832e_acde48001122row4_col1" class="data row4 col1" >0.027594</td>
#                         <td id="T_632bb80e_27af_11eb_832e_acde48001122row4_col2" class="data row4 col2" >0.046561</td>
#                         <td id="T_632bb80e_27af_11eb_832e_acde48001122row4_col3" class="data row4 col3" >-0.340000</td>
#             </tr>
#             <tr>
#                         <th id="T_632bb80e_27af_11eb_832e_acde48001122level0_row5" class="row_heading level0 row5" >ESFP</th>
#                         <td id="T_632bb80e_27af_11eb_832e_acde48001122row5_col0" class="data row5 col0" >48.000000</td>
#                         <td id="T_632bb80e_27af_11eb_832e_acde48001122row5_col1" class="data row5 col1" >0.057889</td>
#                         <td id="T_632bb80e_27af_11eb_832e_acde48001122row5_col2" class="data row5 col2" >0.109902</td>
#                         <td id="T_632bb80e_27af_11eb_832e_acde48001122row5_col3" class="data row5 col3" >-0.080000</td>
#             </tr>
#             <tr>
#                         <th id="T_632bb80e_27af_11eb_832e_acde48001122level0_row6" class="row_heading level0 row6" >ESTJ</th>
#                         <td id="T_632bb80e_27af_11eb_832e_acde48001122row6_col0" class="data row6 col0" >39.000000</td>
#                         <td id="T_632bb80e_27af_11eb_832e_acde48001122row6_col1" class="data row6 col1" >0.053183</td>
#                         <td id="T_632bb80e_27af_11eb_832e_acde48001122row6_col2" class="data row6 col2" >0.129565</td>
#                         <td id="T_632bb80e_27af_11eb_832e_acde48001122row6_col3" class="data row6 col3" >-0.120000</td>
#             </tr>
#             <tr>
#                         <th id="T_632bb80e_27af_11eb_832e_acde48001122level0_row7" class="row_heading level0 row7" >ESTP</th>
#                         <td id="T_632bb80e_27af_11eb_832e_acde48001122row7_col0" class="data row7 col0" >89.000000</td>
#                         <td id="T_632bb80e_27af_11eb_832e_acde48001122row7_col1" class="data row7 col1" >0.065853</td>
#                         <td id="T_632bb80e_27af_11eb_832e_acde48001122row7_col2" class="data row7 col2" >0.132819</td>
#                         <td id="T_632bb80e_27af_11eb_832e_acde48001122row7_col3" class="data row7 col3" >-0.010000</td>
#             </tr>
#             <tr>
#                         <th id="T_632bb80e_27af_11eb_832e_acde48001122level0_row8" class="row_heading level0 row8" >INFJ</th>
#                         <td id="T_632bb80e_27af_11eb_832e_acde48001122row8_col0" class="data row8 col0" >1470.000000</td>
#                         <td id="T_632bb80e_27af_11eb_832e_acde48001122row8_col1" class="data row8 col1" >0.066857</td>
#                         <td id="T_632bb80e_27af_11eb_832e_acde48001122row8_col2" class="data row8 col2" >0.117247</td>
#                         <td id="T_632bb80e_27af_11eb_832e_acde48001122row8_col3" class="data row8 col3" >-0.010000</td>
#             </tr>
#             <tr>
#                         <th id="T_632bb80e_27af_11eb_832e_acde48001122level0_row9" class="row_heading level0 row9" >INFP</th>
#                         <td id="T_632bb80e_27af_11eb_832e_acde48001122row9_col0" class="data row9 col0" >1832.000000</td>
#                         <td id="T_632bb80e_27af_11eb_832e_acde48001122row9_col1" class="data row9 col1" >0.076541</td>
#                         <td id="T_632bb80e_27af_11eb_832e_acde48001122row9_col2" class="data row9 col2" >0.121458</td>
#                         <td id="T_632bb80e_27af_11eb_832e_acde48001122row9_col3" class="data row9 col3" >0.080000</td>
#             </tr>
#             <tr>
#                         <th id="T_632bb80e_27af_11eb_832e_acde48001122level0_row10" class="row_heading level0 row10" >INTJ</th>
#                         <td id="T_632bb80e_27af_11eb_832e_acde48001122row10_col0" class="data row10 col0" >1091.000000</td>
#                         <td id="T_632bb80e_27af_11eb_83

# %% [markdown]
# <a id=emoticons></a>

# %% [markdown]
# <br>
# <br>
#
# ### Use of emoticons
#
# ***

# %%
plt.figure(figsize=(14,8))

sns.set_palette(sns.color_palette(list(colors_types.values())))
sns.boxplot(x='type',y='avg_emoticons_per_post', data=df, order=sorter, showmeans=True, showfliers=False,meanprops={"marker":"s","markerfacecolor":"white", "markeredgecolor":"grey"})
#sns.swarmplot(x='type', y="Total_Emojis", data=df, color='k', alpha=0.3, order=sorter)

plt.title('Number of Emojis used separated by MBTI type', size=15, pad=20)
plt.xlabel('MBTI Type', labelpad=20)
plt.ylabel('Number of emojis used', labelpad=20)

plt.savefig('Figures/Boxplot_Use_Emojis_type.png', dpi=300)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 6))
ax.hist(df.avg_emoticons_per_post, density=False, bins=20)
ax.axes.get_yaxis().set_visible(False)

for rect in ax.patches:
    height = rect.get_height()
    ax.annotate(f'{int(height)}', xy=(rect.get_x()+rect.get_width()/2, height), 
                xytext=(0, 5), textcoords='offset points', ha='center', va='bottom')
    
plt.title('Variable Distribution', pad = 15, size = 15)
plt.show()

# %%
list_array = []

for mtype in mbti_types:
    
    result = df[df['type'] == mtype]['avg_emoticons_per_post']
    list_array.append(result)
    
H, pval = stats.kruskal(list_array[0],list_array[1],list_array[2],list_array[3],
                       list_array[4],list_array[5],list_array[6],list_array[7],
                       list_array[8],list_array[9],list_array[10],list_array[11],
                       list_array[12],list_array[13],list_array[14],list_array[15])
    
print("H-statistic:", H)
print("P-Value:", pval)

if pval < 0.05:
    print("Reject NULL hypothesis - Significant differences exist between groups.")
if pval > 0.05:
    print("Accept NULL hypothesis - No significant difference between groups.")
# Out:
# H-statistic: 592.2439806503324
# P-Value: 1.5771965404133497e-116
# Reject NULL hypothesis - Significant differences exist between groups.

# %% [markdown]
# **Post hoc Dunn's Adjustment**

# %%
dunn = sp.posthoc_dunn(list_array, p_adjust='bonferroni', sort=False)

# %%
dunn.columns = mbti_types
dunn['types'] = mbti_types
dunn = dunn.set_index('types')

# %%
dunn = dunn.round(4)
dunn.style.set_precision(4).applymap(color_dunn)
# Out:
# <style  type="text/css" >
e_acde48001122row5_col5,#T_64edbeb2_27af_11eb_832e_acde48001122row5_col6,#T_64edbeb2_27af_11eb_832e_acde48001122row5_col7,#T_64edbeb2_27af_11eb_832e_acde48001122row5_col8,#T_64edbeb2_27af_11eb_832e_acde48001122row5_col9,#T_64edbeb2_27af_11eb_832e_acde48001122row5_col10,#T_64edbeb2_27af_11eb_832e_acde48001122row5_col11,#T_64edbeb2_27af_11eb_832e_acde48001122row5_col12,#T_64edbeb2_27af_11eb_832e_acde48001122row5_col13,#T_64edbeb2_27af_11eb_832e_acde48001122row5_col14,#T_64edbeb2_27af_11eb_832e_acde48001122row5_col15,#T_64edbeb2_27af_11eb_832e_acde48001122row6_col0,#T_64edbeb2_27af_11eb_832e_acde48001122row6_col1,#T_64edbeb2_27af_11eb_832e_acde48001122row6_col2,#T_64edbeb2_27af_11eb_832e_acde48001122row6_col3,#T_64edbeb2_27af_11eb_832e_acde48001122row6_col4,#T_64edbeb2_27af_11eb_832e_acde48001122row6_col5,#T_64edbeb2_27af_11eb_832e_acde48001122row6_col6,#T_64edbeb2_27af_11eb_832e_acde48001122row6_col7,#T_64edbeb2_27af_11eb_832e_acde48001122row6_col8,#T_64edbeb2_27af_11eb_832e_acde48001122row6_col9,#T_64edbeb2_27af_11eb_832e_acde48001122row6_col10,#T_64edbeb2_27af_11eb_832e_acde48001122row6_col11,#T_64edbeb2_27af_11eb_832e_acde48001122row6_col12,#T_64edbeb2_27af_11eb_832e_acde48001122row6_col13,#T_64edbeb2_27af_11eb_832e_acde48001122row6_col14,#T_64edbeb2_27af_11eb_832e_acde48001122row6_col15,#T_6 ...

# %% [markdown]
# **Effect Size with Hedges' g**

# %%
mean = np.mean(df.avg_emoticons_per_post)
std = np.std(df.avg_emoticons_per_post)
print(mean)
print(std)
# Out:
# 0.05243389284381124
# 0.0907956610090175

# %%
dictionary = {}

for mtype in mbti_types:
    count = len(df[df['type'] == mtype]['avg_emoticons_per_post'])
    mean = np.mean(df[df['type'] == mtype]['avg_emoticons_per_post'])
    std = np.std(df[df['type'] == mtype]['avg_emoticons_per_post'])
    dictionary[mtype] = [count, mean, std]
    print(f'{mtype}: Count = {count}, Mean = {round(mean,2)}, Std = {round(std,2)}')
# Out:
# ENFJ: Count = 190, Mean = 0.09, Std = 0.12
# ENFP: Count = 675, Mean = 0.11, Std = 0.15
# ENTJ: Count = 231, Mean = 0.04, Std = 0.06
# ENTP: Count = 685, Mean = 0.04, Std = 0.07
# ESFJ: Count = 42, Mean = 0.07, Std = 0.12
# ESFP: Count = 48, Mean = 0.06, Std = 0.08
# ESTJ: Count = 39, Mean = 0.05, Std = 0.08
# ESTP: Count = 89, Mean = 0.04, Std = 0.07
# INFJ: Count = 1470, Mean = 0.06, Std = 0.08
# INFP: Count = 1832, Mean = 0.06, Std = 0.09
# INTJ: Count = 1091, Mean = 0.03, Std = 0.05
# INTP: Count = 1304, Mean = 0.03, Std = 0.07
# ISFJ: Count = 166, Mean = 0.08, Std = 0.12
# ISFP: Count = 271, Mean = 0.07, Std = 0.12
# ISTJ: Count = 205, Mean = 0.04, Std = 0.07
# ISTP: Count = 337, Mean = 0.03, Std = 0.06

# %%
hedges = pd.DataFrame(dictionary).T

# %%
hedges.columns = ['Count', 'Mean', 'Std']

# %%
hedges.head(3)
# Out:
#       Count      Mean       Std
# ENFJ  190.0  0.089570  0.123992
# ENFP  675.0  0.107531  0.152893
# ENTJ  231.0  0.035661  0.060372

# %% [markdown]
# [Pooled Standard Deviation](http://goldbook.iupac.org/terms/view/P04758)

# %%
items = []

for i in hedges.iterrows():
    
    result = ((i[1][0]-1)*(i[1][2]**2))
    items.append(result)

pooled_std = np.sqrt((sum(items)) / (hedges.Count.sum() - len(hedges.Count)))
pooled_std
# Out:
# 0.08796150685811636

# %%
items = []

for i in hedges.iterrows():
    result = i[1][0]*i[1][1]
    items.append(result)

pooled_mean = sum(items) / (hedges.Count.sum())
pooled_mean
# Out:
# 0.05243389284381124

# %%
hedges['hedges_g'] = list(map(lambda x : round((x - pooled_mean)/pooled_std,2), hedges['Mean']))

# %%
hedges
hedges.style.applymap(color_rgy, subset=pd.IndexSlice['hedges_g'])
# Out:
# <style  type="text/css" >
# #T_6519dd12_27af_11eb_832e_acde48001122row0_col3,#T_6519dd12_27af_11eb_832e_acde48001122row10_col3,#T_6519dd12_27af_11eb_832e_acde48001122row11_col3,#T_6519dd12_27af_11eb_832e_acde48001122row12_col3,#T_6519dd12_27af_11eb_832e_acde48001122row13_col3,#T_6519dd12_27af_11eb_832e_acde48001122row15_col3{
#             background-color:  lightgreen;
#         }#T_6519dd12_27af_11eb_832e_acde48001122row1_col3{
#             background-color:  orange;
#         }#T_6519dd12_27af_11eb_832e_acde48001122row2_col3,#T_6519dd12_27af_11eb_832e_acde48001122row3_col3,#T_6519dd12_27af_11eb_832e_acde48001122row4_col3,#T_6519dd12_27af_11eb_832e_acde48001122row5_col3,#T_6519dd12_27af_11eb_832e_acde48001122row6_col3,#T_6519dd12_27af_11eb_832e_acde48001122row7_col3,#T_6519dd12_27af_11eb_832e_acde48001122row8_col3,#T_6519dd12_27af_11eb_832e_acde48001122row9_col3,#T_6519dd12_27af_11eb_832e_acde48001122row14_col3{
#             background-color:  None;
#         }</style><table id="T_6519dd12_27af_11eb_832e_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Count</th>        <th class="col_heading level0 col1" >Mean</th>        <th class="col_heading level0 col2" >Std</th>        <th class="col_heading level0 col3" >hedges_g</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6519dd12_27af_11eb_832e_acde48001122level0_row0" class="row_heading level0 row0" >ENFJ</th>
#                         <td id="T_6519dd12_27af_11eb_832e_acde48001122row0_col0" class="data row0 col0" >190.000000</td>
#                         <td id="T_6519dd12_27af_11eb_832e_acde48001122row0_col1" class="data row0 col1" >0.089570</td>
#                         <td id="T_6519dd12_27af_11eb_832e_acde48001122row0_col2" class="data row0 col2" >0.123992</td>
#                         <td id="T_6519dd12_27af_11eb_832e_acde48001122row0_col3" class="data row0 col3" >0.420000</td>
#             </tr>
#             <tr>
#                         <th id="T_6519dd12_27af_11eb_832e_acde48001122level0_row1" class="row_heading level0 row1" >ENFP</th>
#                         <td id="T_6519dd12_27af_11eb_832e_acde48001122row1_col0" class="data row1 col0" >675.000000</td>
#                         <td id="T_6519dd12_27af_11eb_832e_acde48001122row1_col1" class="data row1 col1" >0.107531</td>
#                         <td id="T_6519dd12_27af_11eb_832e_acde48001122row1_col2" class="data row1 col2" >0.152893</td>
#                         <td id="T_6519dd12_27af_11eb_832e_acde48001122row1_col3" class="data row1 col3" >0.630000</td>
#             </tr>
#             <tr>
#                         <th id="T_6519dd12_27af_11eb_832e_acde48001122level0_row2" class="row_heading level0 row2" >ENTJ</th>
#                         <td id="T_6519dd12_27af_11eb_832e_acde48001122row2_col0" class="data row2 col0" >231.000000</td>
#                         <td id="T_6519dd12_27af_11eb_832e_acde48001122row2_col1" class="data row2 col1" >0.035661</td>
#                         <td id="T_6519dd12_27af_11eb_832e_acde48001122row2_col2" class="data row2 col2" >0.060372</td>
#                         <td id="T_6519dd12_27af_11eb_832e_acde48001122row2_col3" class="data row2 col3" >-0.190000</td>
#             </tr>
#             <tr>
#                         <th id="T_6519dd12_27af_11eb_832e_acde48001122level0_row3" class="row_heading level0 row3" >ENTP</th>
#                         <td id="T_6519dd12_27af_11eb_832e_acde48001122row3_col0" class="data row3 col0" >685.000000</td>
#                         <td id="T_6519dd12_27af_11eb_832e_acde48001122row3_col1" class="data row3 col1" >0.043359</td>
#                         <td id="T_6519dd12_27af_11eb_832e_acde48001122row3_col2" class="data row3 col2" >0.072161</td>
#                         <td id="T_6519dd12_27af_11eb_832e_acde48001122row3_col3" class="data row3 col3" >-0.100000</td>
#             </tr>
#             <tr>
#                         <th id="T_6519dd12_27af_11eb_832e_acde48001122level0_row4" class="row_heading level0 row4" >ESFJ</th>
#                         <td id="T_6519dd12_27af_11eb_832e_acde48001122row4_col0" class="data row4 col0" >42.000000</td>
#                         <td id="T_6519dd12_27af_11eb_832e_acde48001122row4_col1" class="data row4 col1" >0.067289</td>
#                         <td id="T_6519dd12_27af_11eb_832e_acde48001122row4_col2" class="data row4 col2" >0.117706</td>
#                         <td id="T_6519dd12_27af_11eb_832e_acde48001122row4_col3" class="data row4 col3" >0.170000</td>
#             </tr>
#             <tr>
#                         <th id="T_6519dd12_27af_11eb_832e_acde48001122level0_row5" class="row_heading level0 row5" >ESFP</th>
#                         <td id="T_6519dd12_27af_11eb_832e_acde48001122row5_col0" class="data row5 col0" >48.000000</td>
#                         <td id="T_6519dd12_27af_11eb_832e_acde48001122row5_col1" class="data row5 col1" >0.062475</td>
#                         <td id="T_6519dd12_27af_11eb_832e_acde48001122row5_col2" class="data row5 col2" >0.081122</td>
#                         <td id="T_6519dd12_27af_11eb_832e_acde48001122row5_col3" class="data row5 col3" >0.110000</td>
#             </tr>
#             <tr>
#                         <th id="T_6519dd12_27af_11eb_832e_acde48001122level0_row6" class="row_heading level0 row6" >ESTJ</th>
#                         <td id="T_6519dd12_27af_11eb_832e_acde48001122row6_col0" class="data row6 col0" >39.000000</td>
#                         <td id="T_6519dd12_27af_11eb_832e_acde48001122row6_col1" class="data row6 col1" >0.052818</td>
#                         <td id="T_6519dd12_27af_11eb_832e_acde48001122row6_col2" class="data row6 col2" >0.080008</td>
#                         <td id="T_6519dd12_27af_11eb_832e_acde48001122row6_col3" class="data row6 col3" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_6519dd12_27af_11eb_832e_acde48001122level0_row7" class="row_heading level0 row7" >ESTP</th>
#                         <td id="T_6519dd12_27af_11eb_832e_acde48001122row7_col0" class="data row7 col0" >89.000000</td>
#                         <td id="T_6519dd12_27af_11eb_832e_acde48001122row7_col1" class="data row7 col1" >0.041525</td>
#                         <td id="T_6519dd12_27af_11eb_832e_acde48001122row7_col2" class="data row7 col2" >0.066576</td>
#                         <td id="T_6519dd12_27af_11eb_832e_acde48001122row7_col3" class="data row7 col3" >-0.120000</td>
#             </tr>
#             <tr>
#                         <th id="T_6519dd12_27af_11eb_832e_acde48001122level0_row8" class="row_heading level0 row8" >INFJ</th>
#                         <td id="T_6519dd12_27af_11eb_832e_acde48001122row8_col0" class="data row8 col0" >1470.000000</td>
#                         <td id="T_6519dd12_27af_11eb_832e_acde48001122row8_col1" class="data row8 col1" >0.057834</td>
#                         <td id="T_6519dd12_27af_11eb_832e_acde48001122row8_col2" class="data row8 col2" >0.084231</td>
#                         <td id="T_6519dd12_27af_11eb_832e_acde48001122row8_col3" class="data row8 col3" >0.060000</td>
#             </tr>
#             <tr>
#                         <th id="T_6519dd12_27af_11eb_832e_acde48001122level0_row9" class="row_heading level0 row9" >INFP</th>
#                         <td id="T_6519dd12_27af_11eb_832e_acde48001122row9_col0" class="data row9 col0" >1832.000000</td>
#                         <td id="T_6519dd12_27af_11eb_832e_acde48001122row9_col1" class="data row9 col1" >0.059687</td>
#                         <td id="T_6519dd12_27af_11eb_832e_acde48001122row9_col2" class="data row9 col2" >0.089194</td>
#                         <td id="T_6519dd12_27af_11eb_832e_acde48001122row9_col3" class="data row9 col3" >0.080000</td>
#             </tr>
#             <tr>
#                         <th id="T_6519dd12_27af_11eb_832e_acde48001122level0_row10" class="row_heading level0 row10" >INTJ</th>
#                         <td id="T_6519dd12_27af_11eb_832e_acde48001122row10_col0" class="data row10 col0" >1091.000000</td>

# %% [markdown]
# <a id=mentions></a>

# %% [markdown]
# <br>
# <br>
#
# ### Mentions
#
# ***

# %%
df.columns
# Out:
# Index(['type', 'I', 'J', 'N', 'T', 'NF', 'NT', 'SP', 'SJ',
#        'avg_num_char_x_post', 'avg_links', 'avg_emoticons_per_post',
#        'avg_self_mentions', 'avg_mentions_others', 'avg_total_mentions',
#        'avg_first_person', 'avg_second_person', 'avg_third_person',
#        'avg_positive_words', 'avg_negative_words'],
#       dtype='object')

# %%
plt.figure(figsize=(14,14))
plt.subplots_adjust(hspace=0.3)


plt.subplot(2,1,1)
sns.set_palette(sns.color_palette(list(colors_types.values())))
sns.boxplot(x='type',y='avg_self_mentions', data=df, order=sorter, showmeans=True, meanprops={"marker":"s","markerfacecolor":"white", "markeredgecolor":"grey"})

plt.title('Average mentions to same MBTI type separated by MBTI type', size=15, pad=20)
plt.xlabel('MBTI Type', labelpad=20)
plt.ylabel('Avg. mention of same MBTI type per post', labelpad=20)


plt.subplot(2,1,2)
sns.set_palette(sns.color_palette(list(colors_types.values())))
sns.boxplot(x='type',y='avg_mentions_others', data=df, order=sorter, showmeans=True, meanprops={"marker":"s","markerfacecolor":"white", "markeredgecolor":"grey"})

plt.title('Average mentions of different MBTI types separated by MBTI type', size=15, pad=20)
plt.xlabel('MBTI Type', labelpad=20)
plt.ylabel('Avg. mention of other MBTI types per post', labelpad=20)


plt.savefig('Figures/Self_mentions_and_mentions_others.png', dpi=300)

plt.show()

# %%
for pronoun in ['avg_self_mentions', 'avg_mentions_others']:
    fig, ax = plt.subplots(figsize=(10, 6))
    ax.hist(df[pronoun], density=False, bins=20)
    ax.axes.get_yaxis().set_visible(False)

    for rect in ax.patches:
        height = rect.get_height()
        ax.annotate(f'{int(height)}', xy=(rect.get_x()+rect.get_width()/2, height), 
                    xytext=(0, 5), textcoords='offset points', ha='center', va='bottom')
    plt.title('Variable Distribution', pad = 15, size = 15)
    plt.show()

# %%
for mentions in ['avg_self_mentions', 'avg_mentions_others']:
    
    list_array = []

    for mtype in mbti_types:

        result = df[df['type'] == mtype][mentions]
        list_array.append(result)

    H, pval = stats.kruskal(list_array[0],list_array[1],list_array[2],list_array[3],
                           list_array[4],list_array[5],list_array[6],list_array[7],
                           list_array[8],list_array[9],list_array[10],list_array[11],
                           list_array[12],list_array[13],list_array[14],list_array[15])

    if mentions == 'avg_self_mentions':
        self_mentions = list_array
    
    else:
        mentions_others = list_array
    
    print(mentions)
    print("H-statistic:", H)
    print("P-Value:", pval)

    if pval < 0.05:
        print("Reject NULL hypothesis - Significant differences exist between groups.")
    if pval > 0.05:
        print("Accept NULL hypothesis - No significant difference between groups.")
        
    print()
# Out:
# avg_self_mentions
# H-statistic: 94.72156857059169
# P-Value: 1.294419496408175e-13
# Reject NULL hypothesis - Significant differences exist between groups.
#
# avg_mentions_others
# H-statistic: 339.7740273193279
# P-Value: 2.882398523899576e-63
# Reject NULL hypothesis - Significant differences exist between groups.

# %% [markdown]
# **Post hoc Dunn's Adjustment**

# %%
dunn = sp.posthoc_dunn(self_mentions, p_adjust='bonferroni', sort=False)

# %%
dunn.columns = mbti_types
dunn['types'] = mbti_types
dunn = dunn.set_index('types')

# %%
dunn = dunn.round(4)
dunn.style.set_precision(4).applymap(color_dunn)
_11eb_832e_acde48001122row3_col10,#T_69550dde_27af_11eb_832e_acde48001122row3_col12,#T_69550dde_27af_11eb_832e_acde48001122row3_col13,#T_69550dde_27af_11eb_832e_acde48001122row3_col14,#T_69550dde_27af_11eb_832e_acde48001122row3_col15,#T_69550dde_27af_11eb_832e_acde48001122row4_col0,#T_69550dde_27af_11eb_832e_acde48001122row4_col1,#T_69550dde_27af_11eb_832e_acde48001122row4_col2,#T_69550dde_27af_11eb_832e_acde48001122row4_col3,#T_69550dde_27af_11eb_832e_acde48001122row4_col4,#T_69550dde_27af_11eb_832e_acde48001122row4_col5,#T_69550dde_27af_11eb_832e_acde48001122row4_col6,#T_69550dde_27af_11eb_832e_acde48001122row4_col7,#T_69550dde_27af_11eb_832e_acde48001122row4_col8,#T_69550dde_27af_11eb_832e_acde48001122row4_col9,#T_69550dde_27af_11eb_832e_acde48001122row4_col10,#T_69550dde_27af_11eb_832e_acde48001122row4_col11,#T_69550dde_27af_11eb_832e_acde48001122row4_col12,#T_69550dde_27af_11eb_832e_acde48001122row4_col13,#T_69550dde_27af_11eb_832e_acde48001122row4_col14,#T_69550dde_27af_11eb_832e_acde48001122row4_col15,#T_69550dde_27af_11eb_832e_acde48001122row5_col0,#T_69550dde_27af_11eb_832e_acde48001122row5_col2,#T_69550dde_27af_11eb_832e_acde48001122row5_col3,#T_69550dde_27af_11eb_832e_acde48001122row5_col4,#T_69550dde_27af_11eb_832e_acde48001122row5_col5,#T_69550dde_27af_11eb_832e_acde48001122row5_col6,#T_69550dde_27af_11eb_832e_acde48001122row5_col7,#T_69550dde_27af_11eb_832e_acde48001122row5_col8,#T_69 ...

# %% [markdown]
# **Effect Size with Hedges' g - Self Mentions**

# %%
mean = np.mean(df.avg_self_mentions)
std = np.std(df.avg_self_mentions)
print(mean)
print(std)
# Out:
# 0.11281453450903364
# 0.09661799636646752

# %%
dictionary = {}

for mtype in mbti_types:
    count = len(df[df['type'] == mtype]['avg_self_mentions'])
    mean = np.mean(df[df['type'] == mtype]['avg_self_mentions'])
    std = np.std(df[df['type'] == mtype]['avg_self_mentions'])
    dictionary[mtype] = [count, mean, std]
    print(f'{mtype}: Count = {count}, Mean = {round(mean,2)}, Std = {round(std,2)}')
# Out:
# ENFJ: Count = 190, Mean = 0.12, Std = 0.1
# ENFP: Count = 675, Mean = 0.13, Std = 0.1
# ENTJ: Count = 231, Mean = 0.11, Std = 0.1
# ENTP: Count = 685, Mean = 0.12, Std = 0.09
# ESFJ: Count = 42, Mean = 0.19, Std = 0.21
# ESFP: Count = 48, Mean = 0.09, Std = 0.11
# ESTJ: Count = 39, Mean = 0.13, Std = 0.12
# ESTP: Count = 89, Mean = 0.13, Std = 0.11
# INFJ: Count = 1470, Mean = 0.11, Std = 0.1
# INFP: Count = 1832, Mean = 0.11, Std = 0.09
# INTJ: Count = 1091, Mean = 0.12, Std = 0.1
# INTP: Count = 1304, Mean = 0.1, Std = 0.09
# ISFJ: Count = 166, Mean = 0.13, Std = 0.11
# ISFP: Count = 271, Mean = 0.1, Std = 0.09
# ISTJ: Count = 205, Mean = 0.11, Std = 0.09
# ISTP: Count = 337, Mean = 0.1, Std = 0.08

# %%
hedges = pd.DataFrame(dictionary).T

# %%
hedges.columns = ['Count', 'Mean', 'Std']

# %%
hedges.head(3)
# Out:
#       Count      Mean       Std
# ENFJ  190.0  0.122849  0.097497
# ENFP  675.0  0.130792  0.101686
# ENTJ  231.0  0.113033  0.102294

# %% [markdown]
# [Pooled Standard Deviation](http://goldbook.iupac.org/terms/view/P04758)

# %%
items = []

for i in hedges.iterrows():
    
    result = ((i[1][0]-1)*(i[1][2]**2))
    items.append(result)

pooled_std = np.sqrt((sum(items)) / (hedges.Count.sum() - len(hedges.Count)))
pooled_std
# Out:
# 0.09597591909147381

# %%
items = []

for i in hedges.iterrows():
    result = i[1][0]*i[1][1]
    items.append(result)

pooled_mean = sum(items) / (hedges.Count.sum())
pooled_mean
# Out:
# 0.11281453450903363

# %%
hedges['hedges_g'] = list(map(lambda x : round((x - pooled_mean)/pooled_std,2), hedges['Mean']))

# %%
hedges
hedges.style.applymap(color_rgy, subset=pd.IndexSlice['hedges_g'])
# Out:
# <style  type="text/css" >
# #T_6985755a_27af_11eb_832e_acde48001122row0_col3,#T_6985755a_27af_11eb_832e_acde48001122row1_col3,#T_6985755a_27af_11eb_832e_acde48001122row2_col3,#T_6985755a_27af_11eb_832e_acde48001122row3_col3,#T_6985755a_27af_11eb_832e_acde48001122row6_col3,#T_6985755a_27af_11eb_832e_acde48001122row7_col3,#T_6985755a_27af_11eb_832e_acde48001122row8_col3,#T_6985755a_27af_11eb_832e_acde48001122row9_col3,#T_6985755a_27af_11eb_832e_acde48001122row10_col3,#T_6985755a_27af_11eb_832e_acde48001122row11_col3,#T_6985755a_27af_11eb_832e_acde48001122row12_col3,#T_6985755a_27af_11eb_832e_acde48001122row13_col3,#T_6985755a_27af_11eb_832e_acde48001122row14_col3,#T_6985755a_27af_11eb_832e_acde48001122row15_col3{
#             background-color:  None;
#         }#T_6985755a_27af_11eb_832e_acde48001122row4_col3{
#             background-color:  red;
#         }#T_6985755a_27af_11eb_832e_acde48001122row5_col3{
#             background-color:  lightgreen;
#         }</style><table id="T_6985755a_27af_11eb_832e_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Count</th>        <th class="col_heading level0 col1" >Mean</th>        <th class="col_heading level0 col2" >Std</th>        <th class="col_heading level0 col3" >hedges_g</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6985755a_27af_11eb_832e_acde48001122level0_row0" class="row_heading level0 row0" >ENFJ</th>
#                         <td id="T_6985755a_27af_11eb_832e_acde48001122row0_col0" class="data row0 col0" >190.000000</td>
#                         <td id="T_6985755a_27af_11eb_832e_acde48001122row0_col1" class="data row0 col1" >0.122849</td>
#                         <td id="T_6985755a_27af_11eb_832e_acde48001122row0_col2" class="data row0 col2" >0.097497</td>
#                         <td id="T_6985755a_27af_11eb_832e_acde48001122row0_col3" class="data row0 col3" >0.100000</td>
#             </tr>
#             <tr>
#                         <th id="T_6985755a_27af_11eb_832e_acde48001122level0_row1" class="row_heading level0 row1" >ENFP</th>
#                         <td id="T_6985755a_27af_11eb_832e_acde48001122row1_col0" class="data row1 col0" >675.000000</td>
#                         <td id="T_6985755a_27af_11eb_832e_acde48001122row1_col1" class="data row1 col1" >0.130792</td>
#                         <td id="T_6985755a_27af_11eb_832e_acde48001122row1_col2" class="data row1 col2" >0.101686</td>
#                         <td id="T_6985755a_27af_11eb_832e_acde48001122row1_col3" class="data row1 col3" >0.190000</td>
#             </tr>
#             <tr>
#                         <th id="T_6985755a_27af_11eb_832e_acde48001122level0_row2" class="row_heading level0 row2" >ENTJ</th>
#                         <td id="T_6985755a_27af_11eb_832e_acde48001122row2_col0" class="data row2 col0" >231.000000</td>
#                         <td id="T_6985755a_27af_11eb_832e_acde48001122row2_col1" class="data row2 col1" >0.113033</td>
#                         <td id="T_6985755a_27af_11eb_832e_acde48001122row2_col2" class="data row2 col2" >0.102294</td>
#                         <td id="T_6985755a_27af_11eb_832e_acde48001122row2_col3" class="data row2 col3" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_6985755a_27af_11eb_832e_acde48001122level0_row3" class="row_heading level0 row3" >ENTP</th>
#                         <td id="T_6985755a_27af_11eb_832e_acde48001122row3_col0" class="data row3 col0" >685.000000</td>
#                         <td id="T_6985755a_27af_11eb_832e_acde48001122row3_col1" class="data row3 col1" >0.116902</td>
#                         <td id="T_6985755a_27af_11eb_832e_acde48001122row3_col2" class="data row3 col2" >0.094592</td>
#                         <td id="T_6985755a_27af_11eb_832e_acde48001122row3_col3" class="data row3 col3" >0.040000</td>
#             </tr>
#             <tr>
#                         <th id="T_6985755a_27af_11eb_832e_acde48001122level0_row4" class="row_heading level0 row4" >ESFJ</th>
#                         <td id="T_6985755a_27af_11eb_832e_acde48001122row4_col0" class="data row4 col0" >42.000000</td>
#                         <td id="T_6985755a_27af_11eb_832e_acde48001122row4_col1" class="data row4 col1" >0.193212</td>
#                         <td id="T_6985755a_27af_11eb_832e_acde48001122row4_col2" class="data row4 col2" >0.205168</td>
#                         <td id="T_6985755a_27af_11eb_832e_acde48001122row4_col3" class="data row4 col3" >0.840000</td>
#             </tr>
#             <tr>
#                         <th id="T_6985755a_27af_11eb_832e_acde48001122level0_row5" class="row_heading level0 row5" >ESFP</th>
#                         <td id="T_6985755a_27af_11eb_832e_acde48001122row5_col0" class="data row5 col0" >48.000000</td>
#                         <td id="T_6985755a_27af_11eb_832e_acde48001122row5_col1" class="data row5 col1" >0.090611</td>
#                         <td id="T_6985755a_27af_11eb_832e_acde48001122row5_col2" class="data row5 col2" >0.112395</td>
#                         <td id="T_6985755a_27af_11eb_832e_acde48001122row5_col3" class="data row5 col3" >-0.230000</td>
#             </tr>
#             <tr>
#                         <th id="T_6985755a_27af_11eb_832e_acde48001122level0_row6" class="row_heading level0 row6" >ESTJ</th>
#                         <td id="T_6985755a_27af_11eb_832e_acde48001122row6_col0" class="data row6 col0" >39.000000</td>
#                         <td id="T_6985755a_27af_11eb_832e_acde48001122row6_col1" class="data row6 col1" >0.129880</td>
#                         <td id="T_6985755a_27af_11eb_832e_acde48001122row6_col2" class="data row6 col2" >0.124049</td>
#                         <td id="T_6985755a_27af_11eb_832e_acde48001122row6_col3" class="data row6 col3" >0.180000</td>
#             </tr>
#             <tr>
#                         <th id="T_6985755a_27af_11eb_832e_acde48001122level0_row7" class="row_heading level0 row7" >ESTP</th>
#                         <td id="T_6985755a_27af_11eb_832e_acde48001122row7_col0" class="data row7 col0" >89.000000</td>
#                         <td id="T_6985755a_27af_11eb_832e_acde48001122row7_col1" class="data row7 col1" >0.129536</td>
#                         <td id="T_6985755a_27af_11eb_832e_acde48001122row7_col2" class="data row7 col2" >0.114835</td>
#                         <td id="T_6985755a_27af_11eb_832e_acde48001122row7_col3" class="data row7 col3" >0.170000</td>
#             </tr>
#             <tr>
#                         <th id="T_6985755a_27af_11eb_832e_acde48001122level0_row8" class="row_heading level0 row8" >INFJ</th>
#                         <td id="T_6985755a_27af_11eb_832e_acde48001122row8_col0" class="data row8 col0" >1470.000000</td>
#                         <td id="T_6985755a_27af_11eb_832e_acde48001122row8_col1" class="data row8 col1" >0.114433</td>
#                         <td id="T_6985755a_27af_11eb_832e_acde48001122row8_col2" class="data row8 col2" >0.096947</td>
#                         <td id="T_6985755a_27af_11eb_832e_acde48001122row8_col3" class="data row8 col3" >0.020000</td>
#             </tr>
#             <tr>
#                         <th id="T_6985755a_27af_11eb_832e_acde48001122level0_row9" class="row_heading level0 row9" >INFP</th>
#                         <td id="T_6985755a_27af_11eb_832e_acde48001122row9_col0" class="data row9 col0" >1832.000000</td>
#                         <td id="T_6985755a_27af_11eb_832e_acde48001122row9_col1" class="data row9 col1" >0.107063</td>
#                         <td id="T_6985755a_27af_11eb_832e_acde48001122row9_col2" class="data row9 col2" >0.093344</td>
#                         <td id="T_6985755a_27af_11eb_832e_acde48001122row9_col3" class="data row9 col3" >-0.060000</td>
#             </tr>
#             <tr>
#                         <th id="T_6985755a_27af_11eb_832e_acde48001122level0_row10" class="row_heading level0 row10" >INTJ</th>
#                         <td id="T_6985755a_27af_11eb_832e_acde48001122row10_col0" class="data row10 col0" >1091.000000</td>

# %% [markdown]
# **Effect Size with Hedges' g - Mentions Others**

# %%
mean = np.mean(df.avg_mentions_others)
std = np.std(df.avg_mentions_others)
print(mean)
print(std)
# Out:
# 0.1851896498094861
# 0.21731004498491116

# %%
dictionary = {}

for mtype in mbti_types:
    count = len(df[df['type'] == mtype]['avg_mentions_others'])
    mean = np.mean(df[df['type'] == mtype]['avg_mentions_others'])
    std = np.std(df[df['type'] == mtype]['avg_mentions_others'])
    dictionary[mtype] = [count, mean, std]
    print(f'{mtype}: Count = {count}, Mean = {round(mean,2)}, Std = {round(std,2)}')
# Out:
# ENFJ: Count = 190, Mean = 0.23, Std = 0.21
# ENFP: Count = 675, Mean = 0.23, Std = 0.23
# ENTJ: Count = 231, Mean = 0.25, Std = 0.24
# ENTP: Count = 685, Mean = 0.23, Std = 0.24
# ESFJ: Count = 42, Mean = 0.32, Std = 0.22
# ESFP: Count = 48, Mean = 0.3, Std = 0.36
# ESTJ: Count = 39, Mean = 0.26, Std = 0.26
# ESTP: Count = 89, Mean = 0.3, Std = 0.32
# INFJ: Count = 1470, Mean = 0.19, Std = 0.22
# INFP: Count = 1832, Mean = 0.15, Std = 0.2
# INTJ: Count = 1091, Mean = 0.17, Std = 0.2
# INTP: Count = 1304, Mean = 0.16, Std = 0.2
# ISFJ: Count = 166, Mean = 0.21, Std = 0.22
# ISFP: Count = 271, Mean = 0.24, Std = 0.27
# ISTJ: Count = 205, Mean = 0.17, Std = 0.22
# ISTP: Count = 337, Mean = 0.14, Std = 0.18

# %%
hedges = pd.DataFrame(dictionary).T

# %%
hedges.columns = ['Count', 'Mean', 'Std']

# %%
hedges.head(3)
# Out:
#       Count      Mean       Std
# ENFJ  190.0  0.226153  0.206475
# ENFP  675.0  0.233026  0.226798
# ENTJ  231.0  0.249530  0.240394

# %% [markdown]
# [Pooled Standard Deviation](http://goldbook.iupac.org/terms/view/P04758)

# %%
items = []

for i in hedges.iterrows():
    
    result = ((i[1][0]-1)*(i[1][2]**2))
    items.append(result)

pooled_std = np.sqrt((sum(items)) / (hedges.Count.sum() - len(hedges.Count)))
pooled_std
# Out:
# 0.21405533426765172

# %%
items = []

for i in hedges.iterrows():
    result = i[1][0]*i[1][1]
    items.append(result)

pooled_mean = sum(items) / (hedges.Count.sum())
pooled_mean
# Out:
# 0.18518964980948607

# %%
hedges['hedges_g'] = list(map(lambda x : round((x - pooled_mean)/pooled_std,2), hedges['Mean']))

# %%
hedges
hedges.style.applymap(color_rgy, subset=pd.IndexSlice['hedges_g'])
# Out:
# <style  type="text/css" >
# #T_69d725bc_27af_11eb_832e_acde48001122row0_col3,#T_69d725bc_27af_11eb_832e_acde48001122row8_col3,#T_69d725bc_27af_11eb_832e_acde48001122row9_col3,#T_69d725bc_27af_11eb_832e_acde48001122row10_col3,#T_69d725bc_27af_11eb_832e_acde48001122row11_col3,#T_69d725bc_27af_11eb_832e_acde48001122row12_col3,#T_69d725bc_27af_11eb_832e_acde48001122row14_col3,#T_69d725bc_27af_11eb_832e_acde48001122row15_col3{
#             background-color:  None;
#         }#T_69d725bc_27af_11eb_832e_acde48001122row1_col3,#T_69d725bc_27af_11eb_832e_acde48001122row2_col3,#T_69d725bc_27af_11eb_832e_acde48001122row3_col3,#T_69d725bc_27af_11eb_832e_acde48001122row6_col3,#T_69d725bc_27af_11eb_832e_acde48001122row13_col3{
#             background-color:  lightgreen;
#         }#T_69d725bc_27af_11eb_832e_acde48001122row4_col3,#T_69d725bc_27af_11eb_832e_acde48001122row5_col3,#T_69d725bc_27af_11eb_832e_acde48001122row7_col3{
#             background-color:  orange;
#         }</style><table id="T_69d725bc_27af_11eb_832e_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Count</th>        <th class="col_heading level0 col1" >Mean</th>        <th class="col_heading level0 col2" >Std</th>        <th class="col_heading level0 col3" >hedges_g</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_69d725bc_27af_11eb_832e_acde48001122level0_row0" class="row_heading level0 row0" >ENFJ</th>
#                         <td id="T_69d725bc_27af_11eb_832e_acde48001122row0_col0" class="data row0 col0" >190.000000</td>
#                         <td id="T_69d725bc_27af_11eb_832e_acde48001122row0_col1" class="data row0 col1" >0.226153</td>
#                         <td id="T_69d725bc_27af_11eb_832e_acde48001122row0_col2" class="data row0 col2" >0.206475</td>
#                         <td id="T_69d725bc_27af_11eb_832e_acde48001122row0_col3" class="data row0 col3" >0.190000</td>
#             </tr>
#             <tr>
#                         <th id="T_69d725bc_27af_11eb_832e_acde48001122level0_row1" class="row_heading level0 row1" >ENFP</th>
#                         <td id="T_69d725bc_27af_11eb_832e_acde48001122row1_col0" class="data row1 col0" >675.000000</td>
#                         <td id="T_69d725bc_27af_11eb_832e_acde48001122row1_col1" class="data row1 col1" >0.233026</td>
#                         <td id="T_69d725bc_27af_11eb_832e_acde48001122row1_col2" class="data row1 col2" >0.226798</td>
#                         <td id="T_69d725bc_27af_11eb_832e_acde48001122row1_col3" class="data row1 col3" >0.220000</td>
#             </tr>
#             <tr>
#                         <th id="T_69d725bc_27af_11eb_832e_acde48001122level0_row2" class="row_heading level0 row2" >ENTJ</th>
#                         <td id="T_69d725bc_27af_11eb_832e_acde48001122row2_col0" class="data row2 col0" >231.000000</td>
#                         <td id="T_69d725bc_27af_11eb_832e_acde48001122row2_col1" class="data row2 col1" >0.249530</td>
#                         <td id="T_69d725bc_27af_11eb_832e_acde48001122row2_col2" class="data row2 col2" >0.240394</td>
#                         <td id="T_69d725bc_27af_11eb_832e_acde48001122row2_col3" class="data row2 col3" >0.300000</td>
#             </tr>
#             <tr>
#                         <th id="T_69d725bc_27af_11eb_832e_acde48001122level0_row3" class="row_heading level0 row3" >ENTP</th>
#                         <td id="T_69d725bc_27af_11eb_832e_acde48001122row3_col0" class="data row3 col0" >685.000000</td>
#                         <td id="T_69d725bc_27af_11eb_832e_acde48001122row3_col1" class="data row3 col1" >0.231661</td>
#                         <td id="T_69d725bc_27af_11eb_832e_acde48001122row3_col2" class="data row3 col2" >0.235361</td>
#                         <td id="T_69d725bc_27af_11eb_832e_acde48001122row3_col3" class="data row3 col3" >0.220000</td>
#             </tr>
#             <tr>
#                         <th id="T_69d725bc_27af_11eb_832e_acde48001122level0_row4" class="row_heading level0 row4" >ESFJ</th>
#                         <td id="T_69d725bc_27af_11eb_832e_acde48001122row4_col0" class="data row4 col0" >42.000000</td>
#                         <td id="T_69d725bc_27af_11eb_832e_acde48001122row4_col1" class="data row4 col1" >0.318219</td>
#                         <td id="T_69d725bc_27af_11eb_832e_acde48001122row4_col2" class="data row4 col2" >0.219874</td>
#                         <td id="T_69d725bc_27af_11eb_832e_acde48001122row4_col3" class="data row4 col3" >0.620000</td>
#             </tr>
#             <tr>
#                         <th id="T_69d725bc_27af_11eb_832e_acde48001122level0_row5" class="row_heading level0 row5" >ESFP</th>
#                         <td id="T_69d725bc_27af_11eb_832e_acde48001122row5_col0" class="data row5 col0" >48.000000</td>
#                         <td id="T_69d725bc_27af_11eb_832e_acde48001122row5_col1" class="data row5 col1" >0.303805</td>
#                         <td id="T_69d725bc_27af_11eb_832e_acde48001122row5_col2" class="data row5 col2" >0.361027</td>
#                         <td id="T_69d725bc_27af_11eb_832e_acde48001122row5_col3" class="data row5 col3" >0.550000</td>
#             </tr>
#             <tr>
#                         <th id="T_69d725bc_27af_11eb_832e_acde48001122level0_row6" class="row_heading level0 row6" >ESTJ</th>
#                         <td id="T_69d725bc_27af_11eb_832e_acde48001122row6_col0" class="data row6 col0" >39.000000</td>
#                         <td id="T_69d725bc_27af_11eb_832e_acde48001122row6_col1" class="data row6 col1" >0.256417</td>
#                         <td id="T_69d725bc_27af_11eb_832e_acde48001122row6_col2" class="data row6 col2" >0.260113</td>
#                         <td id="T_69d725bc_27af_11eb_832e_acde48001122row6_col3" class="data row6 col3" >0.330000</td>
#             </tr>
#             <tr>
#                         <th id="T_69d725bc_27af_11eb_832e_acde48001122level0_row7" class="row_heading level0 row7" >ESTP</th>
#                         <td id="T_69d725bc_27af_11eb_832e_acde48001122row7_col0" class="data row7 col0" >89.000000</td>
#                         <td id="T_69d725bc_27af_11eb_832e_acde48001122row7_col1" class="data row7 col1" >0.301602</td>
#                         <td id="T_69d725bc_27af_11eb_832e_acde48001122row7_col2" class="data row7 col2" >0.320970</td>
#                         <td id="T_69d725bc_27af_11eb_832e_acde48001122row7_col3" class="data row7 col3" >0.540000</td>
#             </tr>
#             <tr>
#                         <th id="T_69d725bc_27af_11eb_832e_acde48001122level0_row8" class="row_heading level0 row8" >INFJ</th>
#                         <td id="T_69d725bc_27af_11eb_832e_acde48001122row8_col0" class="data row8 col0" >1470.000000</td>
#                         <td id="T_69d725bc_27af_11eb_832e_acde48001122row8_col1" class="data row8 col1" >0.185528</td>
#                         <td id="T_69d725bc_27af_11eb_832e_acde48001122row8_col2" class="data row8 col2" >0.216905</td>
#                         <td id="T_69d725bc_27af_11eb_832e_acde48001122row8_col3" class="data row8 col3" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_69d725bc_27af_11eb_832e_acde48001122level0_row9" class="row_heading level0 row9" >INFP</th>
#                         <td id="T_69d725bc_27af_11eb_832e_acde48001122row9_col0" class="data row9 col0" >1832.000000</td>
#                         <td id="T_69d725bc_27af_11eb_832e_acde48001122row9_col1" class="data row9 col1" >0.151271</td>
#                         <td id="T_69d725bc_27af_11eb_832e_acde48001122row9_col2" class="data row9 col2" >0.195156</td>
#                         <td id="T_69d725bc_27af_11eb_832e_acde48001122row9_col3" class="data row9 col3" >-0.160000</td>
#             </tr>
#             <tr>
#                         <th id="T_69d725bc_27af_11eb_832e_acde48001122level0_row10" class="row_heading level0 row10" >INTJ</th>
#                         <td id="T_69d725bc_27af_11eb_832e_acde48001122row10_col0" class="data row10 col0" >1091.000000</td>

# %% [markdown]
# <a id=pronouns></a>

# %% [markdown]
# <br>
# <br>
#
# ### Use of Pronouns
#
# ***

# %%
df.columns
# Out:
# Index(['type', 'I', 'J', 'N', 'T', 'NF', 'NT', 'SP', 'SJ',
#        'avg_num_char_x_post', 'avg_links', 'avg_emoticons_per_post',
#        'avg_self_mentions', 'avg_mentions_others', 'avg_total_mentions',
#        'avg_first_person', 'avg_second_person', 'avg_third_person',
#        'avg_positive_words', 'avg_negative_words'],
#       dtype='object')

# %%
plt.figure(figsize=(14,20))
plt.subplots_adjust(hspace=0.3)


plt.subplot(3,1,1)
sns.set_palette(sns.color_palette(list(colors_types.values())))
sns.boxplot(x='type',y='avg_first_person', data=df, order=sorter, showmeans=True, meanprops={"marker":"s","markerfacecolor":"white", "markeredgecolor":"grey"})

plt.title('Average use of 1st person pronouns per post separated by MBTI type', size=15, pad=20)
plt.xlabel('MBTI Type', labelpad=20)
plt.ylabel('Avg. use of 1st person pronouns per post', labelpad=20)


plt.subplot(3,1,2)
sns.set_palette(sns.color_palette(list(colors_types.values())))
sns.boxplot(x='type',y='avg_second_person', data=df, order=sorter, showmeans=True, meanprops={"marker":"s","markerfacecolor":"white", "markeredgecolor":"grey"})

plt.title('Average use of 2nd person pronouns per post separated by MBTI type', size=15, pad=20)
plt.xlabel('MBTI Type', labelpad=20)
plt.ylabel('Avg. use of 2nd person pronouns per post', labelpad=20)

plt.subplot(3,1,3)
sns.set_palette(sns.color_palette(list(colors_types.values())))
sns.boxplot(x='type',y='avg_third_person', data=df, order=sorter, showmeans=True, meanprops={"marker":"s","markerfacecolor":"white", "markeredgecolor":"grey"})

plt.title('Average use of 3rd person pronouns per post separated by MBTI type', size=15, pad=20)
plt.xlabel('MBTI Type', labelpad=20)
plt.ylabel('Avg. use of 3rd person pronouns per post', labelpad=20)


plt.savefig('Figures/Use_Pronouns.png', dpi=300)

plt.show()

# %% [markdown]
# **Test for Normality**

# %%
for pronoun in ['avg_first_person', 'avg_second_person', 'avg_third_person']:
    fig, ax = plt.subplots(figsize=(10, 6))
    ax.hist(df[pronoun], density=False, bins=20)
    ax.axes.get_yaxis().set_visible(False)

    for rect in ax.patches:
        height = rect.get_height()
        ax.annotate(f'{int(height)}', xy=(rect.get_x()+rect.get_width()/2, height), 
                    xytext=(0, 5), textcoords='offset points', ha='center', va='bottom')
    plt.title('Variable Distribution', pad = 15, size = 15)
    plt.show()

# %%
x = df.avg_first_person

# Shapiro-Wilk normality test
stat, p = stats.shapiro(x)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print('Sample looks Gaussian (fail to reject H0)')
else:
    print('Sample does not look Gaussian (reject H0)')
# Out:
# Statistics=0.997, p=0.000
# Sample does not look Gaussian (reject H0)
# /Users/diego/.pyenv/versions/venv-MBTI/lib/python3.8/site-packages/scipy/stats/morestats.py:1676: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")

# %% [markdown]
# **Kruskal-Wallis Test by Ranks**

# %%
for pronoun in ['avg_first_person', 'avg_second_person', 'avg_third_person']:
    
    list_array = []

    for mtype in mbti_types:

        result = df[df['type'] == mtype][pronoun]
        list_array.append(result)

    H, pval = stats.kruskal(list_array[0],list_array[1],list_array[2],list_array[3],
                           list_array[4],list_array[5],list_array[6],list_array[7],
                           list_array[8],list_array[9],list_array[10],list_array[11],
                           list_array[12],list_array[13],list_array[14],list_array[15])

    if pronoun == 'avg_first_person':
        first_person = list_array
    
    elif pronoun == 'avg_second_person':
        second_person = list_array
    
    else:
        third_person = list_array
    
    print(pronoun)
    print("H-statistic:", H)
    print("P-Value:", pval)

    if pval < 0.05:
        print("Reject NULL hypothesis - Significant differences exist between groups.")
    if pval > 0.05:
        print("Accept NULL hypothesis - No significant difference between groups.")
        
    print()
# Out:
# avg_first_person
# H-statistic: 461.2387713020367
# P-Value: 8.75636889714727e-89
# Reject NULL hypothesis - Significant differences exist between groups.
#
# avg_second_person
# H-statistic: 170.04533190470625
# P-Value: 2.3936595628348836e-28
# Reject NULL hypothesis - Significant differences exist between groups.
#
# avg_third_person
# H-statistic: 78.5806518537404
# P-Value: 1.2683678045017268e-10
# Reject NULL hypothesis - Significant differences exist between groups.

# %% [markdown]
# **Post hoc Dunn's Adjustment**

# %%
dunn = sp.posthoc_dunn(first_person, p_adjust='bonferroni', sort=False)
dunn.columns = mbti_types
dunn['types'] = mbti_types
dunn = dunn.set_index('types')
dunn = dunn.round(4)
dunn.style.set_precision(4).applymap(color_dunn)
# Out:
# <style  type="text/css" >
# #T_70ca5182_27af_11eb_832e_acde48001122row0_col0,#T_70ca5182_27af_11eb_832e_acde48001122row0_col1,#T_70ca5182_27af_11eb_832e_acde48001122row0_col4,#T_70ca5182_27af_11eb_832e_acde48001122row0_col6,#T_70ca5182_27af_11eb_832e_acde48001122row0_col8,#T_70ca5182_27af_11eb_832e_acde48001122row0_col9,#T_70ca5182_27af_11eb_832e_acde48001122row0_col12,#T_70ca5182_27af_11eb_832e_acde48001122row0_col13,#T_70ca5182_27af_11eb_832e_acde48001122row0_col14,#T_70ca5182_27af_11eb_832e_acde48001122row1_col0,#T_70ca5182_27af_11eb_832e_acde48001122row1_col1,#T_70ca5182_27af_11eb_832e_acde48001122row1_
    count = len(df[df['type'] == mtype]['avg_first_person'])
    mean = np.mean(df[df['type'] == mtype]['avg_first_person'])
    std = np.std(df[df['type'] == mtype]['avg_first_person'])
    dictionary[mtype] = [count, mean, std]

# %%
hedges = pd.DataFrame(dictionary).T

# %%
hedges.columns = ['Count', 'Mean', 'Std']

# %%
hedges.head(3)
# Out:
#       Count      Mean       Std
# ENFJ  190.0  2.156065  0.761528
# ENFP  675.0  2.112340  0.687673
# ENTJ  231.0  1.718482  0.641797

# %% [markdown]
# [Pooled Standard Deviation](http://goldbook.iupac.org/terms/view/P04758)

# %%
items = []

for i in hedges.iterrows():
    
    result = ((i[1][0]-1)*(i[1][2]**2))
    items.append(result)

pooled_std = np.sqrt((sum(items)) / (hedges.Count.sum() - len(hedges.Count)))
pooled_std
# Out:
# 0.7004903674997416

# %%
items = []

for i in hedges.iterrows():
    result = i[1][0]*i[1][1]
    items.append(result)

pooled_mean = sum(items) / (hedges.Count.sum())
pooled_mean
# Out:
# 1.9174696275241312

# %%
hedges['hedges_g'] = list(map(lambda x : round((x - pooled_mean)/pooled_std,2), hedges['Mean']))

# %%
def color_rgy(val):
    if val > 0.8 or val < -0.8:
        color = 'red'
        return 'background-color: %s' % color
    elif val > 0.5 or val < -0.5:
        color = 'orange'
        return 'background-color: %s' % color
    elif val > 0.2 or val < -0.2:
        color = 'lightgreen'
        return 'background-color: %s' % color
    else:
        color = None
        return 'background-color: %s' % color

# %%
hedges
hedges.style.applymap(color_rgy, subset=pd.IndexSlice['hedges_g'])
# Out:
# <style  type="text/css" >
# #T_710eeb44_27af_11eb_832e_acde48001122row0_col3,#T_710eeb44_27af_11eb_832e_acde48001122row1_col3,#T_710eeb44_27af_11eb_832e_acde48001122row2_col3,#T_710eeb44_27af_11eb_832e_acde48001122row3_col3,#T_710eeb44_27af_11eb_832e_acde48001122row4_col3,#T_710eeb44_27af_11eb_832e_acde48001122row5_col3,#T_710eeb44_27af_11eb_832e_acde48001122row7_col3,#T_710eeb44_27af_11eb_832e_acde48001122row10_col3,#T_710eeb44_27af_11eb_832e_acde48001122row11_col3,#T_710eeb44_27af_11eb_832e_acde48001122row12_col3,#T_710eeb44_27af_11eb_832e_acde48001122row15_col3{
#             background-color:  lightgreen;
#         }#T_710eeb44_27af_11eb_832e_acde48001122row6_col3,#T_710eeb44_27af_11eb_832e_acde48001122row8_col3,#T_710eeb44_27af_11eb_832e_acde48001122row9_col3,#T_710eeb44_27af_11eb_832e_acde48001122row13_col3,#T_710eeb44_27af_11eb_832e_acde48001122row14_col3{
#             background-color:  None;
#         }</style><table id="T_710eeb44_27af_11eb_832e_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Count</th>        <th class="col_heading level0 col1" >Mean</th>        <th class="col_heading level0 col2" >Std</th>        <th class="col_heading level0 col3" >hedges_g</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_710eeb44_27af_11eb_832e_acde48001122level0_row0" class="row_heading level0 row0" >ENFJ</th>
#                         <td id="T_710eeb44_27af_11eb_832e_acde48001122row0_col0" class="data row0 col0" >190.000000</td>
#                         <td id="T_710eeb44_27af_11eb_832e_acde48001122row0_col1" class="data row0 col1" >2.156065</td>
#                         <td id="T_710eeb44_27af_11eb_832e_acde48001122row0_col2" class="data row0 col2" >0.761528</td>
#                         <td id="T_710eeb44_27af_11eb_832e_acde48001122row0_col3" class="data row0 col3" >0.340000</td>
#             </tr>
#             <tr>
#                         <th id="T_710eeb44_27af_11eb_832e_acde48001122level0_row1" class="row_heading level0 row1" >ENFP</th>
#                         <td id="T_710eeb44_27af_11eb_832e_acde48001122row1_col0" class="data row1 col0" >675.000000</td>
#                         <td id="T_710eeb44_27af_11eb_832e_acde48001122row1_col1" class="data row1 col1" >2.112340</td>
#                         <td id="T_710eeb44_27af_11eb_832e_acde48001122row1_col2" class="data row1 col2" >0.687673</td>
#                         <td id="T_710eeb44_27af_11eb_832e_acde48001122row1_col3" class="data row1 col3" >0.280000</td>
#             </tr>
#             <tr>
#                         <th id="T_710eeb44_27af_11eb_832e_acde48001122level0_row2" class="row_heading level0 row2" >ENTJ</th>
#                         <td id="T_710eeb44_27af_11eb_832e_acde48001122row2_col0" class="data row2 col0" >231.000000</td>
#                         <td id="T_710eeb44_27af_11eb_832e_acde48001122row2_col1" class="data row2 col1" >1.718482</td>
#                         <td id="T_710eeb44_27af_11eb_832e_acde48001122row2_col2" class="data row2 col2" >0.641797</td>
#                         <td id="T_710eeb44_27af_11eb_832e_acde48001122row2_col3" class="data row2 col3" >-0.280000</td>
#             </tr>
#             <tr>
#                         <th id="T_710eeb44_27af_11eb_832e_acde48001122level0_row3" class="row_heading level0 row3" >ENTP</th>
#                         <td id="T_710eeb44_27af_11eb_832e_acde48001122row3_col0" class="data row3 col0" >685.000000</td>
#                         <td id="T_710eeb44_27af_11eb_832e_acde48001122row3_col1" class="data row3 col1" >1.717857</td>
#                         <td id="T_710eeb44_27af_11eb_832e_acde48001122row3_col2" class="data row3 col2" >0.645094</td>
#                         <td id="T_710eeb44_27af_11eb_832e_acde48001122row3_col3" class="data row3 col3" >-0.280000</td>
#             </tr>
#             <tr>
#                         <th id="T_710eeb44_27af_11eb_832e_acde48001122level0_row4" class="row_heading level0 row4" >ESFJ</th>
#                         <td id="T_710eeb44_27af_11eb_832e_acde48001122row4_col0" class="data row4 col0" >42.000000</td>
#                         <td id="T_710eeb44_27af_11eb_832e_acde48001122row4_col1" class="data row4 col1" >2.190691</td>
#                         <td id="T_710eeb44_27af_11eb_832e_acde48001122row4_col2" class="data row4 col2" >0.686891</td>
#                         <td id="T_710eeb44_27af_11eb_832e_acde48001122row4_col3" class="data row4 col3" >0.390000</td>
#             </tr>
#             <tr>
#                         <th id="T_710eeb44_27af_11eb_832e_acde48001122level0_row5" class="row_heading level0 row5" >ESFP</th>
#                         <td id="T_710eeb44_27af_11eb_832e_acde48001122row5_col0" class="data row5 col0" >48.000000</td>
#                         <td id="T_710eeb44_27af_11eb_832e_acde48001122row5_col1" class="data row5 col1" >1.689188</td>
#                         <td id="T_710eeb44_27af_11eb_832e_acde48001122row5_col2" class="data row5 col2" >0.829018</td>
#                         <td id="T_710eeb44_27af_11eb_832e_acde48001122row5_col3" class="data row5 col3" >-0.330000</td>
#             </tr>
#             <tr>
#                         <th id="T_710eeb44_27af_11eb_832e_acde48001122level0_row6" class="row_heading level0 row6" >ESTJ</th>
#                         <td id="T_710eeb44_27af_11eb_832e_acde48001122row6_col0" class="data row6 col0" >39.000000</td>
#                         <td id="T_710eeb44_27af_11eb_832e_acde48001122row6_col1" class="data row6 col1" >1.912215</td>
#                         <td id="T_710eeb44_27af_11eb_832e_acde48001122row6_col2" class="data row6 col2" >0.832724</td>
#                         <td id="T_710eeb44_27af_11eb_832e_acde48001122row6_col3" class="data row6 col3" >-0.010000</td>
#             </tr>
#             <tr>
#                         <th id="T_710eeb44_27af_11eb_832e_acde48001122level0_row7" class="row_heading level0 row7" >ESTP</th>
#                         <td id="T_710eeb44_27af_11eb_832e_acde48001122row7_col0" class="data row7 col0" >89.000000</td>
#                         <td id="T_710eeb44_27af_11eb_832e_acde48001122row7_col1" class="data row7 col1" >1.735107</td>
#                         <td id="T_710eeb44_27af_11eb_832e_acde48001122row7_col2" class="data row7 col2" >0.627877</td>
#                         <td id="T_710eeb44_27af_11eb_832e_acde48001122row7_col3" class="data row7 col3" >-0.260000</td>
#             </tr>
#             <tr>
#                         <th id="T_710eeb44_27af_11eb_832e_acde48001122level0_row8" class="row_heading level0 row8" >INFJ</th>
#                         <td id="T_710eeb44_27af_11eb_832e_acde48001122row8_col0" class="data row8 col0" >1470.000000</td>
#                         <td id="T_710eeb44_27af_11eb_832e_acde48001122row8_col1" class="data row8 col1" >2.047177</td>
#                         <td id="T_710eeb44_27af_11eb_832e_acde48001122row8_col2" class="data row8 col2" >0.714856</td>
#                         <td id="T_710eeb44_27af_11eb_832e_acde48001122row8_col3" class="data row8 col3" >0.190000</td>
#             </tr>
#             <tr>
#                         <th id="T_710eeb44_27af_11eb_832e_acde48001122level0_row9" class="row_heading level0 row9" >INFP</th>
#                         <td id="T_710eeb44_27af_11eb_832e_acde48001122row9_col0" class="data row9 col0" >1832.000000</td>
#                         <td id="T_710eeb44_27af_11eb_832e_acde48001122row9_col1" class="data row9 col1" >2.060135</td>
#                         <td id="T_710eeb44_27af_11eb_832e_acde48001122row9_col2" class="data row9 col2" >0.722619</td>
#                         <td id="T_710eeb44_27af_11eb_832e_acde48001122row9_col3" class="data row9 col3" >0.200000</td>
#             </tr>
#             <tr>
#                         <th id="T_710eeb44_27af_11eb_832e_acde48001122level0_row10" class="row_heading level0 row10" >INTJ</th>
#                         <td id="T_710eeb44_27af_11eb_832e_acde48001122row10_col0" class="data row10 col0" >1091.000000</td>
#                         <td id="T_710eeb44_27af_11eb_832e_a

# %% [markdown]
# **Effect Size with Hedges' g - 2nd Person**

# %%
mean = np.mean(df['avg_second_person'])
std = np.std(df['avg_second_person'])
print('avg_second_person')
print(mean)
print(std)
# Out:
# avg_second_person
# 0.542157227484052
# 0.2807436521655962

# %%
dictionary = {}

for mtype in mbti_types:
    count = len(df[df['type'] == mtype]['avg_second_person'])
    mean = np.mean(df[df['type'] == mtype]['avg_second_person'])
    std = np.std(df[df['type'] == mtype]['avg_second_person'])
    dictionary[mtype] = [count, mean, std]

# %%
hedges = pd.DataFrame(dictionary).T

# %%
hedges.columns = ['Count', 'Mean', 'Std']

# %%
hedges.head(3)
# Out:
#       Count      Mean       Std
# ENFJ  190.0  0.604856  0.273847
# ENFP  675.0  0.582707  0.293039
# ENTJ  231.0  0.650012  0.289288

# %% [markdown]
# [Pooled Standard Deviation](http://goldbook.iupac.org/terms/view/P04758)

# %%
items = []

for i in hedges.iterrows():
    
    result = ((i[1][0]-1)*(i[1][2]**2))
    items.append(result)

pooled_std = np.sqrt((sum(items)) / (hedges.Count.sum() - len(hedges.Count)))
pooled_std
# Out:
# 0.2780137138011088

# %%
items = []

for i in hedges.iterrows():
    result = i[1][0]*i[1][1]
    items.append(result)

pooled_mean = sum(items) / (hedges.Count.sum())
pooled_mean
# Out:
# 0.542157227484052

# %%
hedges['hedges_g'] = list(map(lambda x : round((x - pooled_mean)/pooled_std,2), hedges['Mean']))

# %%
def color_rgy(val):
    if val > 0.8 or val < -0.8:
        color = 'red'
        return 'background-color: %s' % color
    elif val > 0.5 or val < -0.5:
        color = 'orange'
        return 'background-color: %s' % color
    elif val > 0.2 or val < -0.2:
        color = 'lightgreen'
        return 'background-color: %s' % color
    else:
        color = None
        return 'background-color: %s' % color

# %%
hedges
hedges.style.applymap(color_rgy, subset=pd.IndexSlice['hedges_g'])
# Out:
# <style  type="text/css" >
# #T_7167589c_27af_11eb_832e_acde48001122row0_col3,#T_7167589c_27af_11eb_832e_acde48001122row2_col3,#T_7167589c_27af_11eb_832e_acde48001122row13_col3{
#             background-color:  lightgreen;
#         }#T_7167589c_27af_11eb_832e_acde48001122row1_col3,#T_7167589c_27af_11eb_832e_acde48001122row3_col3,#T_7167589c_27af_11eb_832e_acde48001122row4_col3,#T_7167589c_27af_11eb_832e_acde48001122row5_col3,#T_7167589c_27af_11eb_832e_acde48001122row6_col3,#T_7167589c_27af_11eb_832e_acde48001122row7_col3,#T_7167589c_27af_11eb_832e_acde48001122row8_col3,#T_7167589c_27af_11eb_832e_acde48001122row9_col3,#T_7167589c_27af_11eb_832e_acde48001122row10_col3,#T_7167589c_27af_11eb_832e_acde48001122row11_col3,#T_7167589c_27af_11eb_832e_acde48001122row12_col3,#T_7167589c_27af_11eb_832e_acde48001122row14_col3,#T_7167589c_27af_11eb_832e_acde48001122row15_col3{
#             background-color:  None;
#         }</style><table id="T_7167589c_27af_11eb_832e_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Count</th>        <th class="col_heading level0 col1" >Mean</th>        <th class="col_heading level0 col2" >Std</th>        <th class="col_heading level0 col3" >hedges_g</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7167589c_27af_11eb_832e_acde48001122level0_row0" class="row_heading level0 row0" >ENFJ</th>
#                         <td id="T_7167589c_27af_11eb_832e_acde48001122row0_col0" class="data row0 col0" >190.000000</td>
#                         <td id="T_7167589c_27af_11eb_832e_acde48001122row0_col1" class="data row0 col1" >0.604856</td>
#                         <td id="T_7167589c_27af_11eb_832e_acde48001122row0_col2" class="data row0 col2" >0.273847</td>
#                         <td id="T_7167589c_27af_11eb_832e_acde48001122row0_col3" class="data row0 col3" >0.230000</td>
#             </tr>
#             <tr>
#                         <th id="T_7167589c_27af_11eb_832e_acde48001122level0_row1" class="row_heading level0 row1" >ENFP</th>
#                         <td id="T_7167589c_27af_11eb_832e_acde48001122row1_col0" class="data row1 col0" >675.000000</td>
#                         <td id="T_7167589c_27af_11eb_832e_acde48001122row1_col1" class="data row1 col1" >0.582707</td>
#                         <td id="T_7167589c_27af_11eb_832e_acde48001122row1_col2" class="data row1 col2" >0.293039</td>
#                         <td id="T_7167589c_27af_11eb_832e_acde48001122row1_col3" class="data row1 col3" >0.150000</td>
#             </tr>
#             <tr>
#                         <th id="T_7167589c_27af_11eb_832e_acde48001122level0_row2" class="row_heading level0 row2" >ENTJ</th>
#                         <td id="T_7167589c_27af_11eb_832e_acde48001122row2_col0" class="data row2 col0" >231.000000</td>
#                         <td id="T_7167589c_27af_11eb_832e_acde48001122row2_col1" class="data row2 col1" >0.650012</td>
#                         <td id="T_7167589c_27af_11eb_832e_acde48001122row2_col2" class="data row2 col2" >0.289288</td>
#                         <td id="T_7167589c_27af_11eb_832e_acde48001122row2_col3" class="data row2 col3" >0.390000</td>
#             </tr>
#             <tr>
#                         <th id="T_7167589c_27af_11eb_832e_acde48001122level0_row3" class="row_heading level0 row3" >ENTP</th>
#                         <td id="T_7167589c_27af_11eb_832e_acde48001122row3_col0" class="data row3 col0" >685.000000</td>
#                         <td id="T_7167589c_27af_11eb_832e_acde48001122row3_col1" class="data row3 col1" >0.576017</td>
#                         <td id="T_7167589c_27af_11eb_832e_acde48001122row3_col2" class="data row3 col2" >0.281573</td>
#                         <td id="T_7167589c_27af_11eb_832e_acde48001122row3_col3" class="data row3 col3" >0.120000</td>
#             </tr>
#             <tr>
#                         <th id="T_7167589c_27af_11eb_832e_acde48001122level0_row4" class="row_heading level0 row4" >ESFJ</th>
#                         <td id="T_7167589c_27af_11eb_832e_acde48001122row4_col0" class="data row4 col0" >42.000000</td>
#                         <td id="T_7167589c_27af_11eb_832e_acde48001122row4_col1" class="data row4 col1" >0.526425</td>
#                         <td id="T_7167589c_27af_11eb_832e_acde48001122row4_col2" class="data row4 col2" >0.234690</td>
#                         <td id="T_7167589c_27af_11eb_832e_acde48001122row4_col3" class="data row4 col3" >-0.060000</td>
#             </tr>
#             <tr>
#                         <th id="T_7167589c_27af_11eb_832e_acde48001122level0_row5" class="row_heading level0 row5" >ESFP</th>
#                         <td id="T_7167589c_27af_11eb_832e_acde48001122row5_col0" class="data row5 col0" >48.000000</td>
#                         <td id="T_7167589c_27af_11eb_832e_acde48001122row5_col1" class="data row5 col1" >0.494795</td>
#                         <td id="T_7167589c_27af_11eb_832e_acde48001122row5_col2" class="data row5 col2" >0.235303</td>
#                         <td id="T_7167589c_27af_11eb_832e_acde48001122row5_col3" class="data row5 col3" >-0.170000</td>
#             </tr>
#             <tr>
#                         <th id="T_7167589c_27af_11eb_832e_acde48001122level0_row6" class="row_heading level0 row6" >ESTJ</th>
#                         <td id="T_7167589c_27af_11eb_832e_acde48001122row6_col0" class="data row6 col0" >39.000000</td>
#                         <td id="T_7167589c_27af_11eb_832e_acde48001122row6_col1" class="data row6 col1" >0.565918</td>
#                         <td id="T_7167589c_27af_11eb_832e_acde48001122row6_col2" class="data row6 col2" >0.300626</td>
#                         <td id="T_7167589c_27af_11eb_832e_acde48001122row6_col3" class="data row6 col3" >0.090000</td>
#             </tr>
#             <tr>
#                         <th id="T_7167589c_27af_11eb_832e_acde48001122level0_row7" class="row_heading level0 row7" >ESTP</th>
#                         <td id="T_7167589c_27af_11eb_832e_acde48001122row7_col0" class="data row7 col0" >89.000000</td>
#                         <td id="T_7167589c_27af_11eb_832e_acde48001122row7_col1" class="data row7 col1" >0.556439</td>
#                         <td id="T_7167589c_27af_11eb_832e_acde48001122row7_col2" class="data row7 col2" >0.267066</td>
#                         <td id="T_7167589c_27af_11eb_832e_acde48001122row7_col3" class="data row7 col3" >0.050000</td>
#             </tr>
#             <tr>
#                         <th id="T_7167589c_27af_11eb_832e_acde48001122level0_row8" class="row_heading level0 row8" >INFJ</th>
#                         <td id="T_7167589c_27af_11eb_832e_acde48001122row8_col0" class="data row8 col0" >1470.000000</td>
#                         <td id="T_7167589c_27af_11eb_832e_acde48001122row8_col1" class="data row8 col1" >0.578613</td>
#                         <td id="T_7167589c_27af_11eb_832e_acde48001122row8_col2" class="data row8 col2" >0.292642</td>
#                         <td id="T_7167589c_27af_11eb_832e_acde48001122row8_col3" class="data row8 col3" >0.130000</td>
#             </tr>
#             <tr>
#                         <th id="T_7167589c_27af_11eb_832e_acde48001122level0_row9" class="row_heading level0 row9" >INFP</th>
#                         <td id="T_7167589c_27af_11eb_832e_acde48001122row9_col0" class="data row9 col0" >1832.000000</td>
#                         <td id="T_7167589c_27af_11eb_832e_acde48001122row9_col1" class="data row9 col1" >0.508824</td>
#                         <td id="T_7167589c_27af_11eb_832e_acde48001122row9_col2" class="data row9 col2" >0.273620</td>
#                         <td id="T_7167589c_27af_11eb_832e_acde48001122row9_col3" class="data row9 col3" >-0.120000</td>
#             </tr>
#             <tr>
#                         <th id="T_7167589c_27af_11eb_832e_acde48001122level0_row10" class="row_heading level0 row10" >INTJ</th>
#                         <td id="T_7167589c_27af_11eb_832e_acde48001122row10_col0" class="data row10 col0" >1091.000000</td>
#                         <td id="T_7167589c_27af_11eb_832e_acd

# %% [markdown]
# **Effect Size with Hedges' g - 3rd Person**

# %%
mean = np.mean(df['avg_third_person'])
std = np.std(df['avg_third_person'])
print(pronoun)
print(mean)
print(std)
# Out:
# avg_third_person
# 0.41596754497288446
# 0.25239928345744883

# %%
dictionary = {}

for mtype in mbti_types:
    count = len(df[df['type'] == mtype]['avg_third_person'])
    mean = np.mean(df[df['type'] == mtype]['avg_third_person'])
    std = np.std(df[df['type'] == mtype]['avg_third_person'])
    dictionary[mtype] = [count, mean, std]

# %%
hedges = pd.DataFrame(dictionary).T

# %%
hedges.columns = ['Count', 'Mean', 'Std']

# %%
hedges.head(3)
# Out:
#       Count      Mean       Std
# ENFJ  190.0  0.518155  0.316596
# ENFP  675.0  0.458367  0.304990
# ENTJ  231.0  0.442233  0.263301

# %% [markdown]
# [Pooled Standard Deviation](http://goldbook.iupac.org/terms/view/P04758)

# %%
items = []

for i in hedges.iterrows():
    
    result = ((i[1][0]-1)*(i[1][2]**2))
    items.append(result)

pooled_std = np.sqrt((sum(items)) / (hedges.Count.sum() - len(hedges.Count)))
pooled_std
# Out:
# 0.25090778578017303

# %%
items = []

for i in hedges.iterrows():
    result = i[1][0]*i[1][1]
    items.append(result)

pooled_mean = sum(items) / (hedges.Count.sum())
pooled_mean
# Out:
# 0.41596754497288446

# %%
hedges['hedges_g'] = list(map(lambda x : round((x - pooled_mean)/pooled_std,2), hedges['Mean']))

# %%
def color_rgy(val):
    if val > 0.8 or val < -0.8:
        color = 'red'
        return 'background-color: %s' % color
    elif val > 0.5 or val < -0.5:
        color = 'orange'
        return 'background-color: %s' % color
    elif val > 0.2 or val < -0.2:
        color = 'lightgreen'
        return 'background-color: %s' % color
    else:
        color = None
        return 'background-color: %s' % color

# %%
hedges
hedges.style.applymap(color_rgy, subset=pd.IndexSlice['hedges_g'])
# Out:
# <style  type="text/css" >
# #T_71c9b910_27af_11eb_832e_acde48001122row0_col3,#T_71c9b910_27af_11eb_832e_acde48001122row4_col3{
#             background-color:  lightgreen;
#         }#T_71c9b910_27af_11eb_832e_acde48001122row1_col3,#T_71c9b910_27af_11eb_832e_acde48001122row2_col3,#T_71c9b910_27af_11eb_832e_acde48001122row3_col3,#T_71c9b910_27af_11eb_832e_acde48001122row5_col3,#T_71c9b910_27af_11eb_832e_acde48001122row6_col3,#T_71c9b910_27af_11eb_832e_acde48001122row7_col3,#T_71c9b910_27af_11eb_832e_acde48001122row8_col3,#T_71c9b910_27af_11eb_832e_acde48001122row9_col3,#T_71c9b910_27af_11eb_832e_acde48001122row10_col3,#T_71c9b910_27af_11eb_832e_acde48001122row11_col3,#T_71c9b910_27af_11eb_832e_acde48001122row12_col3,#T_71c9b910_27af_11eb_832e_acde48001122row13_col3,#T_71c9b910_27af_11eb_832e_acde48001122row14_col3,#T_71c9b910_27af_11eb_832e_acde48001122row15_col3{
#             background-color:  None;
#         }</style><table id="T_71c9b910_27af_11eb_832e_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Count</th>        <th class="col_heading level0 col1" >Mean</th>        <th class="col_heading level0 col2" >Std</th>        <th class="col_heading level0 col3" >hedges_g</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_71c9b910_27af_11eb_832e_acde48001122level0_row0" class="row_heading level0 row0" >ENFJ</th>
#                         <td id="T_71c9b910_27af_11eb_832e_acde48001122row0_col0" class="data row0 col0" >190.000000</td>
#                         <td id="T_71c9b910_27af_11eb_832e_acde48001122row0_col1" class="data row0 col1" >0.518155</td>
#                         <td id="T_71c9b910_27af_11eb_832e_acde48001122row0_col2" class="data row0 col2" >0.316596</td>
#                         <td id="T_71c9b910_27af_11eb_832e_acde48001122row0_col3" class="data row0 col3" >0.410000</td>
#             </tr>
#             <tr>
#                         <th id="T_71c9b910_27af_11eb_832e_acde48001122level0_row1" class="row_heading level0 row1" >ENFP</th>
#                         <td id="T_71c9b910_27af_11eb_832e_acde48001122row1_col0" class="data row1 col0" >675.000000</td>
#                         <td id="T_71c9b910_27af_11eb_832e_acde48001122row1_col1" class="data row1 col1" >0.458367</td>
#                         <td id="T_71c9b910_27af_11eb_832e_acde48001122row1_col2" class="data row1 col2" >0.304990</td>
#                         <td id="T_71c9b910_27af_11eb_832e_acde48001122row1_col3" class="data row1 col3" >0.170000</td>
#             </tr>
#             <tr>
#                         <th id="T_71c9b910_27af_11eb_832e_acde48001122level0_row2" class="row_heading level0 row2" >ENTJ</th>
#                         <td id="T_71c9b910_27af_11eb_832e_acde48001122row2_col0" class="data row2 col0" >231.000000</td>
#                         <td id="T_71c9b910_27af_11eb_832e_acde48001122row2_col1" class="data row2 col1" >0.442233</td>
#                         <td id="T_71c9b910_27af_11eb_832e_acde48001122row2_col2" class="data row2 col2" >0.263301</td>
#                         <td id="T_71c9b910_27af_11eb_832e_acde48001122row2_col3" class="data row2 col3" >0.100000</td>
#             </tr>
#             <tr>
#                         <th id="T_71c9b910_27af_11eb_832e_acde48001122level0_row3" class="row_heading level0 row3" >ENTP</th>
#                         <td id="T_71c9b910_27af_11eb_832e_acde48001122row3_col0" class="data row3 col0" >685.000000</td>
#                         <td id="T_71c9b910_27af_11eb_832e_acde48001122row3_col1" class="data row3 col1" >0.408339</td>
#                         <td id="T_71c9b910_27af_11eb_832e_acde48001122row3_col2" class="data row3 col2" >0.222634</td>
#                         <td id="T_71c9b910_27af_11eb_832e_acde48001122row3_col3" class="data row3 col3" >-0.030000</td>
#             </tr>
#             <tr>
#                         <th id="T_71c9b910_27af_11eb_832e_acde48001122level0_row4" class="row_heading level0 row4" >ESFJ</th>
#                         <td id="T_71c9b910_27af_11eb_832e_acde48001122row4_col0" class="data row4 col0" >42.000000</td>
#                         <td id="T_71c9b910_27af_11eb_832e_acde48001122row4_col1" class="data row4 col1" >0.529053</td>
#                         <td id="T_71c9b910_27af_11eb_832e_acde48001122row4_col2" class="data row4 col2" >0.294195</td>
#                         <td id="T_71c9b910_27af_11eb_832e_acde48001122row4_col3" class="data row4 col3" >0.450000</td>
#             </tr>
#             <tr>
#                         <th id="T_71c9b910_27af_11eb_832e_acde48001122level0_row5" class="row_heading level0 row5" >ESFP</th>
#                         <td id="T_71c9b910_27af_11eb_832e_acde48001122row5_col0" class="data row5 col0" >48.000000</td>
#                         <td id="T_71c9b910_27af_11eb_832e_acde48001122row5_col1" class="data row5 col1" >0.421837</td>
#                         <td id="T_71c9b910_27af_11eb_832e_acde48001122row5_col2" class="data row5 col2" >0.329852</td>
#                         <td id="T_71c9b910_27af_11eb_832e_acde48001122row5_col3" class="data row5 col3" >0.020000</td>
#             </tr>
#             <tr>
#                         <th id="T_71c9b910_27af_11eb_832e_acde48001122level0_row6" class="row_heading level0 row6" >ESTJ</th>
#                         <td id="T_71c9b910_27af_11eb_832e_acde48001122row6_col0" class="data row6 col0" >39.000000</td>
#                         <td id="T_71c9b910_27af_11eb_832e_acde48001122row6_col1" class="data row6 col1" >0.451172</td>
#                         <td id="T_71c9b910_27af_11eb_832e_acde48001122row6_col2" class="data row6 col2" >0.210915</td>
#                         <td id="T_71c9b910_27af_11eb_832e_acde48001122row6_col3" class="data row6 col3" >0.140000</td>
#             </tr>
#             <tr>
#                         <th id="T_71c9b910_27af_11eb_832e_acde48001122level0_row7" class="row_heading level0 row7" >ESTP</th>
#                         <td id="T_71c9b910_27af_11eb_832e_acde48001122row7_col0" class="data row7 col0" >89.000000</td>
#                         <td id="T_71c9b910_27af_11eb_832e_acde48001122row7_col1" class="data row7 col1" >0.449304</td>
#                         <td id="T_71c9b910_27af_11eb_832e_acde48001122row7_col2" class="data row7 col2" >0.238351</td>
#                         <td id="T_71c9b910_27af_11eb_832e_acde48001122row7_col3" class="data row7 col3" >0.130000</td>
#             </tr>
#             <tr>
#                         <th id="T_71c9b910_27af_11eb_832e_acde48001122level0_row8" class="row_heading level0 row8" >INFJ</th>
#                         <td id="T_71c9b910_27af_11eb_832e_acde48001122row8_col0" class="data row8 col0" >1470.000000</td>
#                         <td id="T_71c9b910_27af_11eb_832e_acde48001122row8_col1" class="data row8 col1" >0.433461</td>
#                         <td id="T_71c9b910_27af_11eb_832e_acde48001122row8_col2" class="data row8 col2" >0.254024</td>
#                         <td id="T_71c9b910_27af_11eb_832e_acde48001122row8_col3" class="data row8 col3" >0.070000</td>
#             </tr>
#             <tr>
#                         <th id="T_71c9b910_27af_11eb_832e_acde48001122level0_row9" class="row_heading level0 row9" >INFP</th>
#                         <td id="T_71c9b910_27af_11eb_832e_acde48001122row9_col0" class="data row9 col0" >1832.000000</td>
#                         <td id="T_71c9b910_27af_11eb_832e_acde48001122row9_col1" class="data row9 col1" >0.399831</td>
#                         <td id="T_71c9b910_27af_11eb_832e_acde48001122row9_col2" class="data row9 col2" >0.233494</td>
#                         <td id="T_71c9b910_27af_11eb_832e_acde48001122row9_col3" class="data row9 col3" >-0.060000</td>
#             </tr>
#             <tr>
#                         <th id="T_71c9b910_27af_11eb_832e_acde48001122level0_row10" class="row_heading level0 row10" >INTJ</th>
#                         <td id="T_71c9b910_27af_11eb_832e_acde48001122row10_col0" class="data row10 col0" >1091.000000</td>
#                         <td id="T_71c9b910_27af_11eb_832e_acde

# %% [markdown]
# <a id=posneg></a>

# %% [markdown]
# <br>
# <br>
#
# ### Use of Positive and Negative Words
#
# ***

# %%
df.columns
# Out:
# Index(['type', 'I', 'J', 'N', 'T', 'NF', 'NT', 'SP', 'SJ',
#        'avg_num_char_x_post', 'avg_links', 'avg_emoticons_per_post',
#        'avg_self_mentions', 'avg_mentions_others', 'avg_total_mentions',
#        'avg_first_person', 'avg_second_person', 'avg_third_person',
#        'avg_positive_words', 'avg_negative_words'],
#       dtype='object')

# %%
plt.figure(figsize=(14,14))
plt.subplots_adjust(hspace=0.3)


plt.subplot(2,1,1)
sns.set_palette(sns.color_palette(list(colors_types.values())))
sns.boxplot(x='type',y='avg_positive_words', data=df, order=sorter, showmeans=True, meanprops={"marker":"s","markerfacecolor":"white", "markeredgecolor":"grey"})

plt.title('Average use of Positive Words per post separated by MBTI type', size=15, pad=20)
plt.xlabel('MBTI Type', labelpad=20)
plt.ylabel('Avg. use of Positive Words per post', labelpad=20)


plt.subplot(2,1,2)
sns.set_palette(sns.color_palette(list(colors_types.values())))
sns.boxplot(x='type',y='avg_negative_words', data=df, order=sorter, showmeans=True, meanprops={"marker":"s","markerfacecolor":"white", "markeredgecolor":"grey"})

plt.title('Average use of Negative Words per post separated by MBTI type', size=15, pad=20)
plt.xlabel('MBTI Type', labelpad=20)
plt.ylabel('Avg. use of Negative Words per post', labelpad=20)


plt.savefig('Figures/Use_Positive_Negative.png', dpi=300)

plt.show()

# %% [markdown]
# **Test for Normality**

# %%
for words in ['avg_positive_words', 'avg_negative_words']:
    fig, ax = plt.subplots(figsize=(10, 6))
    ax.hist(df[words], density=False, bins=20)
    ax.axes.get_yaxis().set_visible(False)

    for rect in ax.patches:
        height = rect.get_height()
        ax.annotate(f'{int(height)}', xy=(rect.get_x()+rect.get_width()/2, height), 
                    xytext=(0, 5), textcoords='offset points', ha='center', va='bottom')
    plt.title('Variable Distribution', pad = 15, size = 15)
    plt.show()

# %%
x = df.avg_positive_words

# Shapiro-Wilk normality test
stat, p = stats.shapiro(x)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print('Sample looks Gaussian (fail to reject H0)')
else:
    print('Sample does not look Gaussian (reject H0)')
# Out:
# Statistics=0.997, p=0.000
# Sample does not look Gaussian (reject H0)
# /Users/diego/.pyenv/versions/venv-MBTI/lib/python3.8/site-packages/scipy/stats/morestats.py:1676: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")

# %% [markdown]
# **Kruskal-Wallis Test by Ranks**

# %%
for words in ['avg_positive_words', 'avg_negative_words']:
    
    list_array = []

    for mtype in mbti_types:

        result = df[df['type'] == mtype][words]
        list_array.append(result)

    H, pval = stats.kruskal(list_array[0],list_array[1],list_array[2],list_array[3],
                           list_array[4],list_array[5],list_array[6],list_array[7],
                           list_array[8],list_array[9],list_array[10],list_array[11],
                           list_array[12],list_array[13],list_array[14],list_array[15])

    if words == 'avg_positive_words':
        positive_words = list_array
    
    else:
        negative_words = list_array
    
    print(pronoun)
    print("H-statistic:", H)
    print("P-Value:", pval)

    if pval < 0.05:
        print("Reject NULL hypothesis - Significant differences exist between groups.")
    if pval > 0.05:
        print("Accept NULL hypothesis - No significant difference between groups.")
        
    print()
# Out:
# avg_third_person
# H-statistic: 370.60401962472514
# P-Value: 1.0206295389287791e-69
# Reject NULL hypothesis - Significant differences exist between groups.
#
# avg_third_person
# H-statistic: 84.30340110869719
# P-Value: 1.1312706705948667e-11
# Reject NULL hypothesis - Significant differences exist between groups.

# %% [markdown]
# **Post hoc Dunn's Adjustment**

# %%
dunn = sp.posthoc_dunn(positive_words, p_adjust='bonferroni', sort=False)
dunn.columns = mbti_types
dunn['types'] = mbti_types
dunn = dunn.set_index('types')
dunn = dunn.round(4)
dunn.style.set_precision(4).applymap(color_dunn)
# Out:
# <style  type="text/css" >
# #T_76db9b30_27af_11eb_832e_acde48001122row0_col0,#T_76db9b30_27af_11eb_832e_acde48001122row0_col1,#T_76db9b30_27af_11eb_832e_acde48001122row0_col4,#T_76db9b30_27af_11eb_832e_acde48001122row0_col6,#T_76db9b30_27af_11eb_832e_acde48001122row0_col8,#T_76db9b30_27af_11eb_832e_acde48001122row0_col9,#T_76db9b30_27af_11eb_832e_acde48001122row0_col12,#T_76db9b30_27af_11eb_832e_acde48001122row1_col0,#T_76db9b30_27af_11eb_832e_acde48001122row1_col1,#T_76db9b30_27af_11eb_832e_acde48001122row1_col4,#T_76db9b30_27af_11eb_832e_acde48001122row1_col6,#T_76db9b30_27af_11eb_832e_acde48001122row1_col12,#T_76db9b30_27af_11eb_832e_acde48001122row2_col2,#T_76db9b30_27af_11eb_832e_acde48001122row2_col3,#T_76db9b30_27af_11eb_832e_acde48001122row2_col4,#T_76db9b30_27af_11eb_832e_acde48001122row2_col5,#T_76
# %% [markdown]
# **Effect Size with Hedges' g - Positive Words**

# %%
mean = np.mean(df['avg_positive_words'])
std = np.std(df['avg_positive_words'])
print('avg_positive_words')
print(mean)
print(std)
# Out:
# avg_positive_words
# 0.8104558938304398
# 0.2629834717098421

# %%
dictionary = {}

for mtype in mbti_types:
    count = len(df[df['type'] == mtype]['avg_positive_words'])
    mean = np.mean(df[df['type'] == mtype]['avg_positive_words'])
    std = np.std(df[df['type'] == mtype]['avg_positive_words'])
    dictionary[mtype] = [count, mean, std]

# %%
hedges = pd.DataFrame(dictionary).T

# %%
hedges.columns = ['Count', 'Mean', 'Std']

# %%
hedges.head(3)
# Out:
#       Count      Mean       Std
# ENFJ  190.0  0.912993  0.270796
# ENFP  675.0  0.907816  0.264488
# ENTJ  231.0  0.796711  0.231039

# %% [markdown]
# [Pooled Standard Deviation](http://goldbook.iupac.org/terms/view/P04758)

# %%
items = []

for i in hedges.iterrows():
    
    result = ((i[1][0]-1)*(i[1][2]**2))
    items.append(result)

pooled_std = np.sqrt((sum(items)) / (hedges.Count.sum() - len(hedges.Count)))
pooled_std
# Out:
# 0.2573390390700272

# %%
items = []

for i in hedges.iterrows():
    result = i[1][0]*i[1][1]
    items.append(result)

pooled_mean = sum(items) / (hedges.Count.sum())
pooled_mean
# Out:
# 0.81045589383044

# %%
hedges['hedges_g'] = list(map(lambda x : round((x - pooled_mean)/pooled_std,2), hedges['Mean']))

# %%
def color_rgy(val):
    if val > 0.8 or val < -0.8:
        color = 'red'
        return 'background-color: %s' % color
    elif val > 0.5 or val < -0.5:
        color = 'orange'
        return 'background-color: %s' % color
    elif val > 0.2 or val < -0.2:
        color = 'lightgreen'
        return 'background-color: %s' % color
    else:
        color = None
        return 'background-color: %s' % color

# %%
hedges
hedges.style.applymap(color_rgy, subset=pd.IndexSlice['hedges_g'])
# Out:
# <style  type="text/css" >
# #T_771d1b3c_27af_11eb_832e_acde48001122row0_col3,#T_771d1b3c_27af_11eb_832e_acde48001122row1_col3,#T_771d1b3c_27af_11eb_832e_acde48001122row4_col3,#T_771d1b3c_27af_11eb_832e_acde48001122row5_col3,#T_771d1b3c_27af_11eb_832e_acde48001122row11_col3,#T_771d1b3c_27af_11eb_832e_acde48001122row15_col3{
#             background-color:  lightgreen;
#         }#T_771d1b3c_27af_11eb_832e_acde48001122row2_col3,#T_771d1b3c_27af_11eb_832e_acde48001122row3_col3,#T_771d1b3c_27af_11eb_832e_acde48001122row6_col3,#T_771d1b3c_27af_11eb_832e_acde48001122row7_col3,#T_771d1b3c_27af_11eb_832e_acde48001122row8_col3,#T_771d1b3c_27af_11eb_832e_acde48001122row9_col3,#T_771d1b3c_27af_11eb_832e_acde48001122row10_col3,#T_771d1b3c_27af_11eb_832e_acde48001122row12_col3,#T_771d1b3c_27af_11eb_832e_acde48001122row13_col3,#T_771d1b3c_27af_11eb_832e_acde48001122row14_col3{
#             background-color:  None;
#         }</style><table id="T_771d1b3c_27af_11eb_832e_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Count</th>        <th class="col_heading level0 col1" >Mean</th>        <th class="col_heading level0 col2" >Std</th>        <th class="col_heading level0 col3" >hedges_g</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_771d1b3c_27af_11eb_832e_acde48001122level0_row0" class="row_heading level0 row0" >ENFJ</th>
#                         <td id="T_771d1b3c_27af_11eb_832e_acde48001122row0_col0" class="data row0 col0" >190.000000</td>
#                         <td id="T_771d1b3c_27af_11eb_832e_acde48001122row0_col1" class="data row0 col1" >0.912993</td>
#                         <td id="T_771d1b3c_27af_11eb_832e_acde48001122row0_col2" class="data row0 col2" >0.270796</td>
#                         <td id="T_771d1b3c_27af_11eb_832e_acde48001122row0_col3" class="data row0 col3" >0.400000</td>
#             </tr>
#             <tr>
#                         <th id="T_771d1b3c_27af_11eb_832e_acde48001122level0_row1" class="row_heading level0 row1" >ENFP</th>
#                         <td id="T_771d1b3c_27af_11eb_832e_acde48001122row1_col0" class="data row1 col0" >675.000000</td>
#                         <td id="T_771d1b3c_27af_11eb_832e_acde48001122row1_col1" class="data row1 col1" >0.907816</td>
#                         <td id="T_771d1b3c_27af_11eb_832e_acde48001122row1_col2" class="data row1 col2" >0.264488</td>
#                         <td id="T_771d1b3c_27af_11eb_832e_acde48001122row1_col3" class="data row1 col3" >0.380000</td>
#             </tr>
#             <tr>
#                         <th id="T_771d1b3c_27af_11eb_832e_acde48001122level0_row2" class="row_heading level0 row2" >ENTJ</th>
#                         <td id="T_771d1b3c_27af_11eb_832e_acde48001122row2_col0" class="data row2 col0" >231.000000</td>
#                         <td id="T_771d1b3c_27af_11eb_832e_acde48001122row2_col1" class="data row2 col1" >0.796711</td>
#                         <td id="T_771d1b3c_27af_11eb_832e_acde48001122row2_col2" class="data row2 col2" >0.231039</td>
#                         <td id="T_771d1b3c_27af_11eb_832e_acde48001122row2_col3" class="data row2 col3" >-0.050000</td>
#             </tr>
#             <tr>
#                         <th id="T_771d1b3c_27af_11eb_832e_acde48001122level0_row3" class="row_heading level0 row3" >ENTP</th>
#                         <td id="T_771d1b3c_27af_11eb_832e_acde48001122row3_col0" class="data row3 col0" >685.000000</td>
#                         <td id="T_771d1b3c_27af_11eb_832e_acde48001122row3_col1" class="data row3 col1" >0.781972</td>
#                         <td id="T_771d1b3c_27af_11eb_832e_acde48001122row3_col2" class="data row3 col2" >0.246691</td>
#                         <td id="T_771d1b3c_27af_11eb_832e_acde48001122row3_col3" class="data row3 col3" >-0.110000</td>
#             </tr>
#             <tr>
#                         <th id="T_771d1b3c_27af_11eb_832e_acde48001122level0_row4" class="row_heading level0 row4" >ESFJ</th>
#                         <td id="T_771d1b3c_27af_11eb_832e_acde48001122row4_col0" class="data row4 col0" >42.000000</td>
#                         <td id="T_771d1b3c_27af_11eb_832e_acde48001122row4_col1" class="data row4 col1" >0.905231</td>
#                         <td id="T_771d1b3c_27af_11eb_832e_acde48001122row4_col2" class="data row4 col2" >0.324448</td>
#                         <td id="T_771d1b3c_27af_11eb_832e_acde48001122row4_col3" class="data row4 col3" >0.370000</td>
#             </tr>
#             <tr>
#                         <th id="T_771d1b3c_27af_11eb_832e_acde48001122level0_row5" class="row_heading level0 row5" >ESFP</th>
#                         <td id="T_771d1b3c_27af_11eb_832e_acde48001122row5_col0" class="data row5 col0" >48.000000</td>
#                         <td id="T_771d1b3c_27af_11eb_832e_acde48001122row5_col1" class="data row5 col1" >0.708524</td>
#                         <td id="T_771d1b3c_27af_11eb_832e_acde48001122row5_col2" class="data row5 col2" >0.283389</td>
#                         <td id="T_771d1b3c_27af_11eb_832e_acde48001122row5_col3" class="data row5 col3" >-0.400000</td>
#             </tr>
#             <tr>
#                         <th id="T_771d1b3c_27af_11eb_832e_acde48001122level0_row6" class="row_heading level0 row6" >ESTJ</th>
#                         <td id="T_771d1b3c_27af_11eb_832e_acde48001122row6_col0" class="data row6 col0" >39.000000</td>
#                         <td id="T_771d1b3c_27af_11eb_832e_acde48001122row6_col1" class="data row6 col1" >0.759134</td>
#                         <td id="T_771d1b3c_27af_11eb_832e_acde48001122row6_col2" class="data row6 col2" >0.308901</td>
#                         <td id="T_771d1b3c_27af_11eb_832e_acde48001122row6_col3" class="data row6 col3" >-0.200000</td>
#             </tr>
#             <tr>
#                         <th id="T_771d1b3c_27af_11eb_832e_acde48001122level0_row7" class="row_heading level0 row7" >ESTP</th>
#                         <td id="T_771d1b3c_27af_11eb_832e_acde48001122row7_col0" class="data row7 col0" >89.000000</td>
#                         <td id="T_771d1b3c_27af_11eb_832e_acde48001122row7_col1" class="data row7 col1" >0.772167</td>
#                         <td id="T_771d1b3c_27af_11eb_832e_acde48001122row7_col2" class="data row7 col2" >0.246052</td>
#                         <td id="T_771d1b3c_27af_11eb_832e_acde48001122row7_col3" class="data row7 col3" >-0.150000</td>
#             </tr>
#             <tr>
#                         <th id="T_771d1b3c_27af_11eb_832e_acde48001122level0_row8" class="row_heading level0 row8" >INFJ</th>
#                         <td id="T_771d1b3c_27af_11eb_832e_acde48001122row8_col0" class="data row8 col0" >1470.000000</td>
#                         <td id="T_771d1b3c_27af_11eb_832e_acde48001122row8_col1" class="data row8 col1" >0.841824</td>
#                         <td id="T_771d1b3c_27af_11eb_832e_acde48001122row8_col2" class="data row8 col2" >0.259682</td>
#                         <td id="T_771d1b3c_27af_11eb_832e_acde48001122row8_col3" class="data row8 col3" >0.120000</td>
#             </tr>
#             <tr>
#                         <th id="T_771d1b3c_27af_11eb_832e_acde48001122level0_row9" class="row_heading level0 row9" >INFP</th>
#                         <td id="T_771d1b3c_27af_11eb_832e_acde48001122row9_col0" class="data row9 col0" >1832.000000</td>
#                         <td id="T_771d1b3c_27af_11eb_832e_acde48001122row9_col1" class="data row9 col1" >0.846775</td>
#                         <td id="T_771d1b3c_27af_11eb_832e_acde48001122row9_col2" class="data row9 col2" >0.261805</td>
#                         <td id="T_771d1b3c_27af_11eb_832e_acde48001122row9_col3" class="data row9 col3" >0.140000</td>
#             </tr>
#             <tr>
#                         <th id="T_771d1b3c_27af_11eb_832e_acde48001122level0_row10" class="row_heading level0 row10" >INTJ</th>
#                         <td id="T_771d1b3c_27af_11eb_832e_acde48001122row10_col0" class="data row10 col0" >1091.000000</td>
#                         <td id="T_771d1b3c_27af_11eb_832e_a

# %% [markdown]
# **Effect Size with Hedges' g - 2nd Person**

# %%
mean = np.mean(df['avg_negative_words'])
std = np.std(df['avg_negative_words'])
print('avg_negative_words')
print(mean)
print(std)
# Out:
# avg_negative_words
# 0.5548096924100051
# 0.20400157955596881

# %%
dictionary = {}

for mtype in mbti_types:
    count = len(df[df['type'] == mtype]['avg_negative_words'])
    mean = np.mean(df[df['type'] == mtype]['avg_negative_words'])
    std = np.std(df[df['type'] == mtype]['avg_negative_words'])
    dictionary[mtype] = [count, mean, std]

# %%
hedges = pd.DataFrame(dictionary).T

# %%
hedges.columns = ['Count', 'Mean', 'Std']

# %%
hedges.head(3)
# Out:
#       Count      Mean       Std
# ENFJ  190.0  0.537347  0.191011
# ENFP  675.0  0.546744  0.188924
# ENTJ  231.0  0.534237  0.182972

# %% [markdown]
# [Pooled Standard Deviation](http://goldbook.iupac.org/terms/view/P04758)

# %%
items = []

for i in hedges.iterrows():
    
    result = ((i[1][0]-1)*(i[1][2]**2))
    items.append(result)

pooled_std = np.sqrt((sum(items)) / (hedges.Count.sum() - len(hedges.Count)))
pooled_std
# Out:
# 0.2029804537722436

# %%
items = []

for i in hedges.iterrows():
    result = i[1][0]*i[1][1]
    items.append(result)

pooled_mean = sum(items) / (hedges.Count.sum())
pooled_mean
# Out:
# 0.5548096924100051

# %%
hedges['hedges_g'] = list(map(lambda x : round((x - pooled_mean)/pooled_std,2), hedges['Mean']))

# %%
def color_rgy(val):
    if val > 0.8 or val < -0.8:
        color = 'red'
        return 'background-color: %s' % color
    elif val > 0.5 or val < -0.5:
        color = 'orange'
        return 'background-color: %s' % color
    elif val > 0.2 or val < -0.2:
        color = 'lightgreen'
        return 'background-color: %s' % color
    else:
        color = None
        return 'background-color: %s' % color

# %%
hedges
hedges.style.applymap(color_rgy, subset=pd.IndexSlice['hedges_g'])
# Out:
# <style  type="text/css" >
# #T_7753d0b4_27af_11eb_832e_acde48001122row0_col3,#T_7753d0b4_27af_11eb_832e_acde48001122row1_col3,#T_7753d0b4_27af_11eb_832e_acde48001122row2_col3,#T_7753d0b4_27af_11eb_832e_acde48001122row3_col3,#T_7753d0b4_27af_11eb_832e_acde48001122row4_col3,#T_7753d0b4_27af_11eb_832e_acde48001122row7_col3,#T_7753d0b4_27af_11eb_832e_acde48001122row8_col3,#T_7753d0b4_27af_11eb_832e_acde48001122row9_col3,#T_7753d0b4_27af_11eb_832e_acde48001122row10_col3,#T_7753d0b4_27af_11eb_832e_acde48001122row11_col3,#T_7753d0b4_27af_11eb_832e_acde48001122row12_col3,#T_7753d0b4_27af_11eb_832e_acde48001122row14_col3,#T_7753d0b4_27af_11eb_832e_acde48001122row15_col3{
#             background-color:  None;
#         }#T_7753d0b4_27af_11eb_832e_acde48001122row5_col3,#T_7753d0b4_27af_11eb_832e_acde48001122row6_col3,#T_7753d0b4_27af_11eb_832e_acde48001122row13_col3{
#             background-color:  lightgreen;
#         }</style><table id="T_7753d0b4_27af_11eb_832e_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Count</th>        <th class="col_heading level0 col1" >Mean</th>        <th class="col_heading level0 col2" >Std</th>        <th class="col_heading level0 col3" >hedges_g</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7753d0b4_27af_11eb_832e_acde48001122level0_row0" class="row_heading level0 row0" >ENFJ</th>
#                         <td id="T_7753d0b4_27af_11eb_832e_acde48001122row0_col0" class="data row0 col0" >190.000000</td>
#                         <td id="T_7753d0b4_27af_11eb_832e_acde48001122row0_col1" class="data row0 col1" >0.537347</td>
#                         <td id="T_7753d0b4_27af_11eb_832e_acde48001122row0_col2" class="data row0 col2" >0.191011</td>
#                         <td id="T_7753d0b4_27af_11eb_832e_acde48001122row0_col3" class="data row0 col3" >-0.090000</td>
#             </tr>
#             <tr>
#                         <th id="T_7753d0b4_27af_11eb_832e_acde48001122level0_row1" class="row_heading level0 row1" >ENFP</th>
#                         <td id="T_7753d0b4_27af_11eb_832e_acde48001122row1_col0" class="data row1 col0" >675.000000</td>
#                         <td id="T_7753d0b4_27af_11eb_832e_acde48001122row1_col1" class="data row1 col1" >0.546744</td>
#                         <td id="T_7753d0b4_27af_11eb_832e_acde48001122row1_col2" class="data row1 col2" >0.188924</td>
#                         <td id="T_7753d0b4_27af_11eb_832e_acde48001122row1_col3" class="data row1 col3" >-0.040000</td>
#             </tr>
#             <tr>
#                         <th id="T_7753d0b4_27af_11eb_832e_acde48001122level0_row2" class="row_heading level0 row2" >ENTJ</th>
#                         <td id="T_7753d0b4_27af_11eb_832e_acde48001122row2_col0" class="data row2 col0" >231.000000</td>
#                         <td id="T_7753d0b4_27af_11eb_832e_acde48001122row2_col1" class="data row2 col1" >0.534237</td>
#                         <td id="T_7753d0b4_27af_11eb_832e_acde48001122row2_col2" class="data row2 col2" >0.182972</td>
#                         <td id="T_7753d0b4_27af_11eb_832e_acde48001122row2_col3" class="data row2 col3" >-0.100000</td>
#             </tr>
#             <tr>
#                         <th id="T_7753d0b4_27af_11eb_832e_acde48001122level0_row3" class="row_heading level0 row3" >ENTP</th>
#                         <td id="T_7753d0b4_27af_11eb_832e_acde48001122row3_col0" class="data row3 col0" >685.000000</td>
#                         <td id="T_7753d0b4_27af_11eb_832e_acde48001122row3_col1" class="data row3 col1" >0.555869</td>
#                         <td id="T_7753d0b4_27af_11eb_832e_acde48001122row3_col2" class="data row3 col2" >0.197840</td>
#                         <td id="T_7753d0b4_27af_11eb_832e_acde48001122row3_col3" class="data row3 col3" >0.010000</td>
#             </tr>
#             <tr>
#                         <th id="T_7753d0b4_27af_11eb_832e_acde48001122level0_row4" class="row_heading level0 row4" >ESFJ</th>
#                         <td id="T_7753d0b4_27af_11eb_832e_acde48001122row4_col0" class="data row4 col0" >42.000000</td>
#                         <td id="T_7753d0b4_27af_11eb_832e_acde48001122row4_col1" class="data row4 col1" >0.519670</td>
#                         <td id="T_7753d0b4_27af_11eb_832e_acde48001122row4_col2" class="data row4 col2" >0.180334</td>
#                         <td id="T_7753d0b4_27af_11eb_832e_acde48001122row4_col3" class="data row4 col3" >-0.170000</td>
#             </tr>
#             <tr>
#                         <th id="T_7753d0b4_27af_11eb_832e_acde48001122level0_row5" class="row_heading level0 row5" >ESFP</th>
#                         <td id="T_7753d0b4_27af_11eb_832e_acde48001122row5_col0" class="data row5 col0" >48.000000</td>
#                         <td id="T_7753d0b4_27af_11eb_832e_acde48001122row5_col1" class="data row5 col1" >0.471626</td>
#                         <td id="T_7753d0b4_27af_11eb_832e_acde48001122row5_col2" class="data row5 col2" >0.145728</td>
#                         <td id="T_7753d0b4_27af_11eb_832e_acde48001122row5_col3" class="data row5 col3" >-0.410000</td>
#             </tr>
#             <tr>
#                         <th id="T_7753d0b4_27af_11eb_832e_acde48001122level0_row6" class="row_heading level0 row6" >ESTJ</th>
#                         <td id="T_7753d0b4_27af_11eb_832e_acde48001122row6_col0" class="data row6 col0" >39.000000</td>
#                         <td id="T_7753d0b4_27af_11eb_832e_acde48001122row6_col1" class="data row6 col1" >0.512554</td>
#                         <td id="T_7753d0b4_27af_11eb_832e_acde48001122row6_col2" class="data row6 col2" >0.208766</td>
#                         <td id="T_7753d0b4_27af_11eb_832e_acde48001122row6_col3" class="data row6 col3" >-0.210000</td>
#             </tr>
#             <tr>
#                         <th id="T_7753d0b4_27af_11eb_832e_acde48001122level0_row7" class="row_heading level0 row7" >ESTP</th>
#                         <td id="T_7753d0b4_27af_11eb_832e_acde48001122row7_col0" class="data row7 col0" >89.000000</td>
#                         <td id="T_7753d0b4_27af_11eb_832e_acde48001122row7_col1" class="data row7 col1" >0.529617</td>
#                         <td id="T_7753d0b4_27af_11eb_832e_acde48001122row7_col2" class="data row7 col2" >0.197681</td>
#                         <td id="T_7753d0b4_27af_11eb_832e_acde48001122row7_col3" class="data row7 col3" >-0.120000</td>
#             </tr>
#             <tr>
#                         <th id="T_7753d0b4_27af_11eb_832e_acde48001122level0_row8" class="row_heading level0 row8" >INFJ</th>
#                         <td id="T_7753d0b4_27af_11eb_832e_acde48001122row8_col0" class="data row8 col0" >1470.000000</td>
#                         <td id="T_7753d0b4_27af_11eb_832e_acde48001122row8_col1" class="data row8 col1" >0.566136</td>
#                         <td id="T_7753d0b4_27af_11eb_832e_acde48001122row8_col2" class="data row8 col2" >0.211640</td>
#                         <td id="T_7753d0b4_27af_11eb_832e_acde48001122row8_col3" class="data row8 col3" >0.060000</td>
#             </tr>
#             <tr>
#                         <th id="T_7753d0b4_27af_11eb_832e_acde48001122level0_row9" class="row_heading level0 row9" >INFP</th>
#                         <td id="T_7753d0b4_27af_11eb_832e_acde48001122row9_col0" class="data row9 col0" >1832.000000</td>
#                         <td id="T_7753d0b4_27af_11eb_832e_acde48001122row9_col1" class="data row9 col1" >0.578066</td>
#                         <td id="T_7753d0b4_27af_11eb_832e_acde48001122row9_col2" class="data row9 col2" >0.213215</td>
#                         <td id="T_7753d0b4_27af_11eb_832e_acde48001122row9_col3" class="data row9 col3" >0.110000</td>
#             </tr>
#             <tr>
#                         <th id="T_7753d0b4_27af_11eb_832e_acde48001122level0_row10" class="row_heading level0 row10" >INTJ</th>
#                         <td id="T_7753d0b4_27af_11eb_832e_acde48001122row10_col0" class="data row10 col0" >1091.000000</td>
#                         <td id="T_7753d0b4_27af_11eb_832e

# %% [markdown]
# <a id=dicho></a>

# %% [markdown]
# ## The 4 dichotomies

# %%
barplots_data = df.iloc[:,1:5].mean()

# %%
barplots_data
# Out:
# I    0.769568
# J    0.395850
# N    0.862017
# T    0.458905
# dtype: float64

# %%
df_dummies = df_global['code'].str.get_dummies('')
df_dummies = df_dummies.drop(['E','S','F','P'], axis=1)
df_global = df_global.join(df_dummies)

# %%
attributes = []

for a in ['I','J','N','T']:
    number = df_global.groupby(a).sum().iloc[1,0]
    attributes.append(number)

# %%
attributes
# Out:
# [0.5089333333333333,
#  0.4448666666666667,
#  0.6098833333333334,
#  0.2633333333333333]

# %%
fig.canvas.draw()

fig, ax = plt.subplots(2,2, figsize=(8,10))
fig.subplots_adjust(hspace=0.7)

sns.despine(bottom=True, left=True)
x = np.arange(0,2)
x_ticks_labels = ['Dataset','Population\n Estimate']

fig.canvas.draw()

ax[0,0].bar(0, height=barplots_data[0], color=colors_main['I'], edgecolor='white', width=0.8, label="Introversion")
ax[0,0].bar(0, height=(1-barplots_data[0]), bottom=barplots_data[0], color=colors_main['E'], edgecolor='white', width=0.8, label="Extraversion")
ax[0,0].bar(1, height=attributes[0], color=colors_main['I'], edgecolor='white', width=0.8)
ax[0,0].bar(1, height=(1-attributes[0]), bottom=attributes[0], color=colors_main['E'], edgecolor='white', width=0.8)
ax[0,0].set_title('Extraversion vs. Introversion')
ax[0,0].legend(loc=0, bbox_to_anchor=(0.94,0), ncol=2)

ax[0,1].bar(0, height=barplots_data[2], color=colors_main['N'], edgecolor='white', width=0.8, label="Intuition        ")
ax[0,1].bar(0, height=(1-barplots_data[2]), bottom=barplots_data[2], color=colors_main['S'], edgecolor='white', width=0.8, label="Sensing")
ax[0,1].bar(1, height=attributes[2], color=colors_main['N'], edgecolor='white', width=0.8)
ax[0,1].bar(1, height=(1-attributes[2]), bottom=attributes[2], color=colors_main['S'], edgecolor='white', width=0.8)
ax[0,1].set_title('Intuition vs. Sensing')
ax[0,1].legend(loc='best', bbox_to_anchor=(0.91,0), ncol=2)

ax[1,0].bar(0, height=barplots_data[3], color=colors_main['T'], edgecolor='white', width=0.8, label="Thinking    ")
ax[1,0].bar(0, height=(1-barplots_data[3]), bottom=barplots_data[3], color=colors_main['F'], edgecolor='white', width=0.8, label="Feeling")
ax[1,0].bar(1, height=attributes[3], color=colors_main['T'], edgecolor='white', width=0.8)
ax[1,0].bar(1, height=(1-attributes[3]), bottom=attributes[3], color=colors_main['F'], edgecolor='white', width=0.8)
ax[1,0].set_title('Thinking vs. Feeling')
ax[1,0].legend(loc='best', bbox_to_anchor=(0.88,-0.15), ncol=2)
ax[1,0].set_xticks(x) # Set number of ticks for x-axis
ax[1,0].set_xticklabels(x_ticks_labels, fontsize=10) # Set ticks labels for x-axis

ax[1,1].bar(0, height=barplots_data[1], color=colors_main['J'], edgecolor='white', width=0.8, label="Judging")
ax[1,1].bar(0, height=(1-barplots_data[1]), bottom=barplots_data[1], color=colors_main['P'], edgecolor='white', width=0.8, label="Perceiving")
ax[1,1].bar(1, height=attributes[1], color=colors_main['J'], edgecolor='white', width=0.8)
ax[1,1].bar(1, height=(1-attributes[1]), bottom=attributes[1], color=colors_main['P'], edgecolor='white', width=0.8)
ax[1,1].set_title('Judging vs. Perceiving')
ax[1,1].legend(loc='best', bbox_to_anchor=(0.88,-0.15), ncol=2)
ax[1,1].set_xticks(x) # Set number of ticks for x-axis
ax[1,1].set_xticklabels(x_ticks_labels, fontsize=10) # Set ticks labels for x-axis

for ax in fig.get_axes():
    ax.label_outer()

plt.figtext(.5,1,'Preferences distribution in dataset vs. population estimate',fontsize=15,ha='center')

plt.tight_layout()
plt.savefig('Figures/percent_dataset_attributes_population.png', dpi=300, bbox_inches='tight')
                   
plt.show()

# %% [markdown]
# <a id=heatmapd></a>

# %% [markdown]
# <br>
#
# ### Heatmap
# ***

# %% [markdown]
# There are many variables in our dataset that are similar amongst them. We will focus on 5 variables:
# - Average number of characters per post
# - Number of links
# - How many times the reference their own MBTI type (self mentions)
# - Total number of emojis they use

# %%
df_heatmap = df.set_index('I')
df_norm_col=(df_heatmap-df_heatmap.mean())/df_heatmap.std()
IE = df_norm_col.drop(['J','N','T','NT','NF','SP','SJ','type'], axis=1).groupby('I').mean()
IE.rename(index={0: 'E',1:'I'}, inplace=True)

# %%
df_heatmap = df.set_index('N')
df_norm_col=(df_heatmap-df_heatmap.mean())/df_heatmap.std()
NS = df_norm_col.drop(['J','I','T','NT','NF','SP','SJ','type'], axis=1).groupby('N').mean()
NS.rename(index={0: 'S',1:'N'}, inplace=True)

# %%
df_heatmap = df.set_index('T')
df_norm_col=(df_heatmap-df_heatmap.mean())/df_heatmap.std()
TF = df_norm_col.drop(['J','N','I','NT','NF','SP','SJ','type'], axis=1).groupby('T').mean()
TF.rename(index={0: 'F',1:'T'}, inplace=True)

# %%
df_heatmap = df.set_index('J')
df_norm_col=(df_heatmap-df_heatmap.mean())/df_heatmap.std()
JP = df_norm_col.drop(['I','N','T','NT','NF','SP','SJ','type'], axis=1).groupby('J').mean()
JP.rename(index={0: 'P',1:'J'}, inplace=True)

# %%
dicot_heatmap = IE.append([NS,TF,JP])
dicot_heatmap = dicot_heatmap[['avg_num_char_x_post', 'avg_emoticons_per_post', 'avg_links', 
'avg_self_mentions', 'avg_mentions_others', 'avg_total_mentions', 
'avg_negative_words', 'avg_positive_words',
'avg_first_person', 'avg_second_person', 'avg_third_person']]

# %%
plt.figure(figsize=(12,6))
           
ax = sns.heatmap(dicot_heatmap, cmap='RdYlBu_r', linewidths=0.5, annot=True)

plt.ylabel('MBTI Types', labelpad=20)
plt.yticks(rotation = 0)
plt.title('Heatmap of MBTI dichotomies and parameters (average)', size=15, pad=20)

plt.tight_layout()
plt.savefig('Figures/Heatmap_Dichotomies.png', dpi=300)

plt.show()

# %% [markdown]
# <a id=charactersd></a>

# %% [markdown]
# <br>
#
# ### Avg. Number of characters per post
# ***

# %%
EI = df.set_index('I')
EI.rename(index={0: 'E',1:'I'}, inplace=True)
SN = df.set_index('N')
SN.rename(index={0: 'S',1:'N'}, inplace=True)
FT = df.set_index('T')
FT.rename(index={0: 'F',1:'T'}, inplace=True)
PJ = df.set_index('N')
PJ.rename(index={0: 'P',1:'J'}, inplace=True)

# %%
df_boxplots = EI.append([SN,FT,PJ])

# %%
ordered_colors = [colors_main['I'],colors_main['E'],
 colors_main['N'],colors_main['S'],
 colors_main['F'],colors_main['T'],
 colors_main['J'],colors_main['P']]

# %%
colors_main
# Out:
# {'I': '#a50026',
#  'E': '#d73027',
#  'S': '#f46d43',
#  'N': '#fdae61',
#  'T': '#fee090',
#  'F': '#ffffbf',
#  'P': '#e0f3f8',
#  'J': '#abd9e9'}

# %% [markdown]
# <a id=charactersd></a>

# %%
plt.figure(figsize=(14,8))

sns.set_palette(sns.color_palette(ordered_colors))
sns.boxplot(x=df_boxplots.index,y='avg_num_char_x_post', data=df_boxplots, showmeans=True, meanprops={"marker":"s","markerfacecolor":"white", "markeredgecolor":"grey"})

plt.title('Average Number of Characters per post separated by MBTI dichotomies', size=15, pad=20)
plt.xlabel('', labelpad=20)
plt.ylabel('Avg. number of characters per post', labelpad=20)

plt.savefig('Figures/Boxplot_Num_Characters_Dichotomies.png', dpi=300)

plt.show()

# %% [markdown]
# <a id=linksd></a>

# %% [markdown]
# <a id=linksd></a>

# %%
plt.figure(figsize=(14,8))

sns.set_palette(sns.color_palette(ordered_colors))
sns.boxplot(x=df_boxplots.index,y='avg_links', data=df_boxplots, showfliers=False, showmeans=True, meanprops={"marker":"s","markerfacecolor":"white", "markeredgecolor":"grey"})

plt.title('Average Number of links per post separated by MBTI dichotomies', size=15, pad=20)
plt.xlabel('', labelpad=20)
plt.ylabel('Avg. number of links per post', labelpad=20)

plt.savefig('Figures/Boxplot_Num_Links_Dichotomies.png', dpi=300)

plt.show()

# %% [markdown]
# <a id=emoticonsd></a>

# %%
plt.figure(figsize=(14,8))

sns.set_palette(sns.color_palette(ordered_colors))
sns.boxplot(x=df_boxplots.index,y='avg_emoticons_per_post', data=df_boxplots, showfliers=False, showmeans=True, meanprops={"marker":"s","markerfacecolor":"white", "markeredgecolor":"grey"})

plt.title('Average Number of Emoticons per post separated by MBTI dichotomies', size=15, pad=20)
plt.xlabel('', labelpad=20)
plt.ylabel('Avg. number of emoticons per post', labelpad=20)

plt.savefig('Figures/Boxplot_Num_Characters_Dichotomies.png', dpi=300)

plt.show()

# %% [markdown]
# <a id=mentionsd></a>

# %%
plt.figure(figsize=(14,14))
plt.subplots_adjust(hspace=0.3)

plt.subplot(2,1,1)
sns.set_palette(sns.color_palette(ordered_colors))
sns.boxplot(x=df_boxplots.index,y='avg_self_mentions', data=df_boxplots, showfliers=False, showmeans=True, meanprops={"marker":"s","markerfacecolor":"white", "markeredgecolor":"grey"})

plt.title('Average mentions to same MBTI type separated by dichotomies', size=15, pad=20)
plt.xlabel('', labelpad=20)
plt.ylabel('Avg. mention of same MBTI type per post', labelpad=20)


plt.subplot(2,1,2)
sns.set_palette(sns.color_palette(list(colors_types.values())))
sns.boxplot(x=df_boxplots.index,y='avg_mentions_others', data=df_boxplots, showfliers=False, showmeans=True, meanprops={"marker":"s","markerfacecolor":"white", "markeredgecolor":"grey"})

plt.title('Average mentions of different MBTI types separated by dichotomies', size=15, pad=20)
plt.xlabel('', labelpad=20)
plt.ylabel('Avg. mention of other MBTI types per post', labelpad=20)

plt.savefig('Figures/Self_mentions_and_mentions_others_Dichotomies.png', dpi=300)

plt.show()

# %% [markdown]
# <a id=pronounsd></a>

# %%
plt.figure(figsize=(14,20))
plt.subplots_adjust(hspace=0.3)

plt.subplot(3,1,1)
sns.set_palette(sns.color_palette(ordered_colors))
sns.boxplot(x=df_boxplots.index, y='avg_first_person', data=df_boxplots, showfliers=False, showmeans=True, meanprops={"marker":"s","markerfacecolor":"white", "markeredgecolor":"grey"})

plt.title('Average use of 1st person pronouns per post separated by dichotomies', size=15, pad=20)
plt.xlabel('', labelpad=20)
plt.ylabel('Avg. use of 1st person pronouns per post', labelpad=20)

plt.subplot(3,1,2)
sns.set_palette(sns.color_palette(ordered_colors))
sns.boxplot(x=df_boxplots.index, y='avg_second_person', data=df_boxplots, showfliers=False, showmeans=True, meanprops={"marker":"s","markerfacecolor":"white", "markeredgecolor":"grey"})

plt.title('Average use of 2nd person pronouns per post separated by dichotomies', size=15, pad=20)
plt.xlabel('', labelpad=20)
plt.ylabel('Avg. use of 2nd person pronouns per post', labelpad=20)

plt.subplot(3,1,3)
sns.set_palette(sns.color_palette(ordered_colors))
sns.boxplot(x=df_boxplots.index, y='avg_third_person', data=df_boxplots, showfliers=False, showmeans=True, meanprops={"marker":"s","markerfacecolor":"white", "markeredgecolor":"grey"})

plt.title('Average use of 3rd person pronouns per post separated by dichotomies', size=15, pad=20)
plt.xlabel('', labelpad=20)
plt.ylabel('Avg. use of 3rd person pronouns per post', labelpad=20)

plt.savefig('Figures/Use_Pronouns_Dichotomies.png', dpi=300)

plt.show()

# %% [markdown]
# <a id=posnegd></a>

# %%
plt.figure(figsize=(14,14))
plt.subplots_adjust(hspace=0.3)

plt.subplot(2,1,1)
sns.set_palette(sns.color_palette(ordered_colors))
sns.boxplot(x=df_boxplots.index,y='avg_positive_words', data=df_boxplots, showmeans=True, meanprops={"marker":"s","markerfacecolor":"white", "markeredgecolor":"grey"})

plt.title('Average use of Positive Words per post separated by dichotomies', size=15, pad=20)
plt.xlabel('', labelpad=20)
plt.ylabel('Avg. use of Positive Words per post', labelpad=20)

plt.subplot(2,1,2)
sns.set_palette(sns.color_palette(ordered_colors))
sns.boxplot(x=df_boxplots.index,y='avg_negative_words', data=df_boxplots, showmeans=True, meanprops={"marker":"s","markerfacecolor":"white", "markeredgecolor":"grey"})

plt.title('Average use of Negative Words per post separated by dichotomies', size=15, pad=20)
plt.xlabel('', labelpad=20)
plt.ylabel('Avg. use of Negative Words per post', labelpad=20)

plt.savefig('Figures/Use_Positive_Negative_Dichotomies.png', dpi=300)

plt.show()

# %% [markdown]
# **Test for Normality**

# %%
for words in ['avg_positive_words', 'avg_negative_words']:
    fig, ax = plt.subplots(figsize=(10, 6))
    ax.hist(df_boxplots[words], density=False, bins=20)
    ax.axes.get_yaxis().set_visible(False)

    for rect in ax.patches:
        height = rect.get_height()
        ax.annotate(f'{int(height)}', xy=(rect.get_x()+rect.get_width()/2, height), 
                    xytext=(0, 5), textcoords='offset points', ha='center', va='bottom')
    plt.title('Variable Distribution', pad = 15, size = 15)
    plt.show()

# %%
x = df_boxplots.avg_positive_words

# Shapiro-Wilk normality test
stat, p = stats.shapiro(x)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print('Sample looks Gaussian (fail to reject H0)')
else:
    print('Sample does not look Gaussian (reject H0)')
# Out:
# Statistics=0.997, p=0.000
# Sample does not look Gaussian (reject H0)
# /Users/diego/.pyenv/versions/venv-MBTI/lib/python3.8/site-packages/scipy/stats/morestats.py:1676: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")

# %% [markdown]
# **Mann-Whitney U**

# %%
df_dicho = df_boxplots.reset_index()

# %%
for words in ['avg_positive_words', 'avg_negative_words']:
    
    x = df_dicho[df_dicho['index'] == 'J'][words]
    y = df_dicho[df_dicho['index'] == 'P'][words]
    H, pval = stats.mannwhitneyu(x=x, y=y)
    print("I and E")
    print("H-statistic:", H)
    print("P-Value:", pval)

    if pval < 0.05:
        print("Reject NULL hypothesis - Significant differences exist between groups.")
    if pval > 0.05:
        print("Accept NULL hypothesis - No significant difference between groups.")
        
    print()
# Out:
# I and E
# H-statistic: 4121415.5
# P-Value: 5.3290826368571224e-06
# Reject NULL hypothesis - Significant differences exist between groups.
#
# I and E
# H-statistic: 3915999.5
# P-Value: 1.7224662858300828e-12
# Reject NULL hypothesis - Significant differences exist between groups.
